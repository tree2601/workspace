# %%
# ==================== 最小实现：统一配置（只改这里） ====================

# ---- 服务配置（OpenAI-compatible）----
HOST_IP = "61.169.215.178"
LLM_PORT = 10000
EMBEDDING_PORT = 10004
RERANKER_PORT = 10005
API_KEY = "xtsk"

LLM_MODEL = "LLM"
EMBEDDING_MODEL = "EMBEDDING"
RERANKER_MODEL = "RERANKER"

# ---- pgvector 配置 ----
PG_HOST = "61.169.215.186"
PG_PORT = 15432
PG_DB = "vectordb"
PG_USER = "admin"
PG_PASSWORD = "xtsk@2024"

# ---- 向量维度（Qwen3 Matryoshka 截断）----
TARGET_DIM = 1536  # pgvector index 限制 2000 维

# ---- 运行参数 ----
INGEST_N_CASES = 5269
MAX_WORKERS = 5
LLM_TIMEOUT_S = 80
EMBED_TIMEOUT_S = 60
RERANK_TIMEOUT_S = 30

# ---- imports / clients ----
import json
import time
from datetime import datetime
from typing import Dict, List, Optional, TypedDict, Annotated, Sequence

import requests
import psycopg2
from openai import OpenAI

EMBEDDING_URL = f"http://{HOST_IP}:{EMBEDDING_PORT}"
RERANKER_URL = f"http://{HOST_IP}:{RERANKER_PORT}"
LLM_BASE_URL = f"http://{HOST_IP}:{LLM_PORT}/v1"

DB_CONFIG = {
    "host": PG_HOST,
    "port": PG_PORT,
    "database": PG_DB,
    "user": PG_USER,
    "password": PG_PASSWORD,
}

llm_client = OpenAI(api_key=API_KEY, base_url=LLM_BASE_URL)


def log(msg: str):
    print(f"[{datetime.now().strftime('%H:%M:%S')}] {msg}")


log("✅ config loaded")
log(f"LLM={LLM_BASE_URL} model={LLM_MODEL} timeout={LLM_TIMEOUT_S}s")
log(f"EMB={EMBEDDING_URL} model={EMBEDDING_MODEL} truncate={TARGET_DIM} timeout={EMBED_TIMEOUT_S}s")
log(f"RERANK={RERANKER_URL} model={RERANKER_MODEL} timeout={RERANK_TIMEOUT_S}s")
log(f"PG={PG_HOST}:{PG_PORT}/{PG_DB}")
log(f"INGEST_N_CASES={INGEST_N_CASES} MAX_WORKERS={MAX_WORKERS}")
# Out:
# [17:39:11] ✅ config loaded
# [17:39:11] LLM=http://61.169.215.178:10000/v1 model=LLM timeout=80s
# [17:39:11] EMB=http://61.169.215.178:10004 model=EMBEDDING truncate=1536 timeout=60s
# [17:39:11] RERANK=http://61.169.215.178:10005 model=RERANKER timeout=30s
# [17:39:11] PG=61.169.215.186:15432/vectordb
# [17:39:11] INGEST_N_CASES=5269 MAX_WORKERS=5

# %%
# ==================== LLM 结构化抽取 ====================

with open("corpus/_all_cases.json", "r", encoding="utf-8") as f:
    all_cases = json.load(f)

STRUCTURE_PROMPT = """你是中医医案结构化专家。请将以下医案内容提取为标准 JSON。

只输出 JSON：
{
  \"patient\": {\"age\": int|null, \"sex\": \"男\"|\"女\"|null},
  \"chief_complaint\": str|null,
  \"tcm_diagnosis\": str|null,
  \"western_diagnosis\": str|null,
  \"tcm_pattern\": str|null,
  \"treatment_principle\": str|null,
  \"prescriptions\": [{\"visit\": str, \"herbs\": [{\"name\": str, \"dose\": str}], \"days\": int|null}],
  \"outcome\": str|null,
  \"summary\": str
}

字段为空用 null。

医案内容：
"""


def strip_code_fence(text: str) -> str:
    t = (text or "").strip()
    if t.startswith("```"):
        parts = t.split("```")
        if len(parts) >= 2:
            t = parts[1].strip()
            if t.startswith("json"):
                t = t[4:].strip()
    return t


def extract_case_structure(content: str, max_retries: int = 3) -> Optional[Dict]:
    for attempt in range(1, max_retries + 1):
        try:
            resp = llm_client.chat.completions.create(
                model=LLM_MODEL,
                messages=[
                    {"role": "system", "content": "只输出 JSON。"},
                    {"role": "user", "content": STRUCTURE_PROMPT + content[:5000]},
                ],
                temperature=0,
                timeout=LLM_TIMEOUT_S,
            )
            return json.loads(strip_code_fence(resp.choices[0].message.content))
        except Exception as e:
            log(f"LLM extract failed attempt={attempt}/{max_retries}: {str(e)[:120]}")
            if attempt < max_retries:
                time.sleep(2)
    return None


log(f"cases loaded: {all_cases.get('count')} total")
log(f"preview: {all_cases['cases'][0]['content'][:120]}...")
# Out:
# [17:39:51] cases loaded: 5269 total
# [17:39:51] preview: 现症: 夜睡  $1 \sim 2 \mathrm{~h}$ , 或通宵难寐。体温正常, 但畏寒恶风, 头痛头重未解, 胸闷泛恶, 身重乏力, 午后身热, 时有手抖, 口干, 咽部不适, 喉间生痰, 色黄质黏。舌苔灰黄, 脉细而濡。
#
# 中医...

# %%
# ==================== 建表 + 入库（前 N 条） ====================

from concurrent.futures import ThreadPoolExecutor, as_completed
from threading import Lock


def init_tables():
    conn = psycopg2.connect(**DB_CONFIG)
    cur = conn.cursor()

    cur.execute("DROP TABLE IF EXISTS tcm_case_embedding CASCADE;")
    cur.execute("DROP TABLE IF EXISTS tcm_case CASCADE;")

    cur.execute(
        """
        CREATE TABLE tcm_case (
            id SERIAL PRIMARY KEY,
            source_md TEXT,
            case_index INT,
            raw_content TEXT,
            clean_json JSONB,
            sex TEXT,
            age INT,
            tcm_pattern TEXT,
            tcm_diagnosis TEXT,
            western_diagnosis TEXT,
            summary TEXT,
            created_at TIMESTAMP DEFAULT NOW()
        );
        """
    )

    cur.execute(
        f"""
        CREATE TABLE tcm_case_embedding (
            id SERIAL PRIMARY KEY,
            case_id INT REFERENCES tcm_case(id) ON DELETE CASCADE,
            view TEXT,
            content TEXT,
            embedding vector({TARGET_DIM}),
            created_at TIMESTAMP DEFAULT NOW()
        );
        """
    )

    cur.execute("CREATE INDEX idx_embedding_view ON tcm_case_embedding(view);")

    cur.execute(
        """
        CREATE INDEX idx_embedding_vector
        ON tcm_case_embedding
        USING hnsw (embedding vector_cosine_ops);
        """
    )

    conn.commit()
    cur.close()
    conn.close()


def embed_truncated(text: str, max_retries: int = 3) -> Optional[List[float]]:
    url = f"{EMBEDDING_URL}/v1/embeddings"
    headers = {"Content-Type": "application/json", "Authorization": f"Bearer {API_KEY}"}
    payload = {"model": EMBEDDING_MODEL, "input": [text]}

    for attempt in range(1, max_retries + 1):
        try:
            r = requests.post(url, headers=headers, json=payload, timeout=EMBED_TIMEOUT_S)
            r.raise_for_status()
            full = r.json()["data"][0]["embedding"]
            return full[:TARGET_DIM]
        except Exception as e:
            if attempt == max_retries:
                log(f"embedding failed: {str(e)[:120]}")
                return None
            time.sleep(1)


def process_one_case(case_data: Dict, idx: int, total: int) -> bool:
    log(f"[{idx}/{total}] start {case_data['source_md']}#{case_data['index']}")

    t0 = time.time()
    structured = extract_case_structure(case_data["content"], max_retries=3)
    t_llm = time.time() - t0

    if not structured:
        log(f"[{idx}/{total}] LLM failed ({t_llm:.1f}s)")
        return False

    log(f"[{idx}/{total}] LLM ok ({t_llm:.1f}s)")

    conn = psycopg2.connect(**DB_CONFIG)
    cur = conn.cursor()

    cur.execute(
        """
        INSERT INTO tcm_case (source_md, case_index, raw_content, clean_json, sex, age, tcm_pattern, tcm_diagnosis, western_diagnosis, summary)
        VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
        RETURNING id;
        """,
        (
            case_data["source_md"],
            case_data["index"],
            case_data["content"],
            json.dumps(structured, ensure_ascii=False),
            (structured.get("patient") or {}).get("sex"),
            (structured.get("patient") or {}).get("age"),
            structured.get("tcm_pattern"),
            structured.get("tcm_diagnosis"),
            structured.get("western_diagnosis"),
            structured.get("summary"),
        ),
    )
    case_id = cur.fetchone()[0]

    views = [
        ("summary", structured.get("summary") or ""),
        ("pattern", f"{structured.get('tcm_pattern') or ''} {structured.get('treatment_principle') or ''}".strip()),
    ]

    for view, content in views:
        if not content:
            continue
        t1 = time.time()
        emb = embed_truncated(content[:500], max_retries=3)
        t_emb = time.time() - t1
        if emb is None:
            log(f"[{idx}/{total}] embedding failed view={view} ({t_emb:.1f}s)")
            continue
        cur.execute(
            """INSERT INTO tcm_case_embedding (case_id, view, content, embedding) VALUES (%s,%s,%s,%s);""",
            (case_id, view, content, emb),
        )
        log(f"[{idx}/{total}] embedding ok view={view} ({t_emb:.1f}s)")

    conn.commit()
    cur.close()
    conn.close()

    log(f"[{idx}/{total}] done case_id={case_id}\n")
    return True


init_tables()

cases_to_ingest = all_cases["cases"][:INGEST_N_CASES]
log(f"ingest N={len(cases_to_ingest)} workers={MAX_WORKERS}")

ok = 0
fail = 0
lock = Lock()

with ThreadPoolExecutor(max_workers=MAX_WORKERS) as ex:
    futures = [ex.submit(process_one_case, c, i + 1, len(cases_to_ingest)) for i, c in enumerate(cases_to_ingest)]
    for fu in as_completed(futures):
        try:
            success = fu.result()
        except Exception as e:
            success = False
            log(f"task exception: {str(e)[:120]}")

        with lock:
            ok += 1 if success else 0
            fail += 0 if success else 1

log(f"ingest done success={ok} fail={fail}")
# Out:
# [17:39:57] ingest N=5269 workers=5
# [17:39:57] [1/5269] start 上海名老中医医案精选.md#1
# [17:39:57] [2/5269] start 上海名老中医医案精选.md#2
# [17:39:57] [3/5269] start 上海名老中医医案精选.md#3
# [17:39:57] [4/5269] start 上海名老中医医案精选.md#4
# [17:39:57] [5/5269] start 上海名老中医医案精选.md#5
# [17:40:28] [1/5269] LLM ok (31.5s)
# [17:40:29] [1/5269] embedding ok view=summary (0.1s)
# [17:40:29] [1/5269] embedding ok view=pattern (0.1s)
# [17:40:29] [1/5269] done case_id=1
#
# [17:40:29] [6/5269] start 上海名老中医医案精选.md#6
# [17:40:31] [3/5269] LLM ok (34.3s)
# [17:40:32] [3/5269] embedding ok view=summary (0.1s)
# [17:40:32] [3/5269] embedding ok view=pattern (0.1s)
# [17:40:32] [3/5269] done case_id=2
#
# [17:40:32] [7/5269] start 上海名老中医医案精选.md#7
# [17:40:35] [5/5269] LLM ok (38.1s)
# [17:40:35] [5/5269] embedding ok view=summary (0.1s)
# [17:40:35] [5/5269] embedding ok view=pattern (0.1s)
# [17:40:35] [5/5269] done case_id=3
#
# [17:40:35] [8/5269] start 上海名老中医医案精选.md#8
# [17:40:43] [2/5269] LLM ok (45.6s)
# [17:40:43] [2/5269] embedding ok view=summary (0.1s)
# [17:40:43] [2/5269] embedding ok view=pattern (0.1s)
# [17:40:43] [2/5269] done case_id=4
#
# [17:40:43] [9/5269] start 上海名老中医医案精选.md#9
# [17:40:58] [4/5269] LLM ok (61.3s)
# [17:40:59] [4/5269] embedding ok view=summary (0.1s)
# [17:40:59] [4/5269] embedding ok view=pattern (0.1s)
# [17:40:59] [4/5269] done case_id=5
#
# [17:40:59] [10/5269] start 上海名老中医医案精选.md#10
# [17:41:00] [8/5269] LLM ok (24.4s)
# [17:41:00] [8/5269] embedding ok view=summary (0.1s)
# [17:41:00] [8/5269] embedding ok view=pattern (0.1s)
# [17:41:00] [8/5269] done case_id=6
#
# [17:41:00] [11/5269] start 上海名老中医医案精选.md#11
# [17:41:04] [7/5269] LLM ok (32.3s)
# [17:41:04] [7/5269] embedding ok view=summary (0.1s)
# [17:41:04] [7/5269] embedding ok view=pattern (0.1s)
# [17:41:04] [7/5269] done case_id=7
#
# [17:41:04] [12/5269] start 上海名老中医医案精选.md#12
# [17:41:06] [6/5269] LLM ok (37.2s)
# [17:41:06] [6/5269] embedding ok view=summary (0.1s)
# [17:41:06] [6/5269] embedding ok view=pattern (0.1s)
# [17:41:06] [6/5269] done case_id=8
#
# [17:41:06] [13/5269] start 上海名老中医医案精选.md#13
# [17:41:15] [9/5269] LLM ok (31.9s)
# [17:41:15] [9/5269] embedding ok view=summary (0.1s)
# [17:41:15] [9/5269] embedding ok view=pattern (0.1s)
# [17:41:15] [9/5269] done case_id=9
#
# [17:41:15] [14/5269] start 上海名老中医医案精选.md#14
# [17:41:30] [10/5269] LLM ok (31.0s)
# [17:41:30] [10/5269] embedding ok view=summary (0.1s)
# [17:41:30] [10/5269] embedding ok view=pattern (0.1s)
# [17:41:30] [10/5269] done case_id=10
#
# [17:41:30] [15/5269] start 上海名老中医医案精选.md#15
# [17:41:31] [12/5269] LLM ok (27.0s)
# [17:41:32] [12/5269] embedding ok view=summary (0.1s)
# [17:41:32] [12/5269] embedding ok view=pattern (0.1s)
# [17:41:32] [12/5269] done case_id=11
#
# [17:41:32] [16/5269] start 上海名老中医医案精选.md#16
# [17:41:37] [11/5269] LLM ok (37.2s)
# [17:41:38] [11/5269] embedding ok view=summary (0.1s)
# [17:41:38] [11/5269] embedding ok view=pattern (0.1s)
# [17:41:38] [11/5269] done case_id=12
#
# [17:41:38] [17/5269] start 上海名老中医医案精选.md#17
# [17:41:43] [13/5269] LLM ok (36.5s)
# [17:41:43] [13/5269] embedding ok view=summary (0.1s)
# [17:41:43] [13/5269] embedding ok view=pattern (0.1s)
# [17:41:43] [13/5269] done case_id=13
#
# [17:41:43] [18/5269] start 上海名老中医医案精选.md#18
# [17:41:59] [14/5269] LLM ok (43.5s)
# [17:41:59] [14/5269] embedding ok view=summary (0.1s)
# [17:41:59] [14/5269] embedding ok view=pattern (0.1s)
# [17:41:59] [14/5269] done case_id=14
#
# [17:41:59] [19/5269] start 上海名老中医医案精选.md#19
# [17:42:10] [16/5269] LLM ok (38.2s)
# [17:42:10] [16/5269] embedding ok view=summary (0.1s)
# [17:42:10] [16/5269] embedding ok view=pattern (0.1s)
# [17:42:10] [16/5269] done case_id=15
#
# [17:42:10] [20/5269] start 上海名老中医医案精选.md#20
# [17:42:17] [17/5269] LLM ok (39.2s)
# [17:42:17] [17/5269] embedding ok view=summary (0.1s)
# [17:42:17] [17/5269] embedding ok view=pattern (0.1s)
# [17:42:17] [17/5269] done case_id=16
#
# [17:42:17] [21/5269] start 上海名老中医医案精选.md#21
# [17:42:20] [15/5269] LLM ok (50.5s)
# [17:42:21] [15/5269] embedding ok view=summary (0.1s)
# [17:42:21] [15/5269] embedding ok view=pattern (0.1s)
# [17:42:21] [15/5269] done case_id=17
#
# [17:42:21] [22/5269] start 上海名老中医医案精选.md#22
# [17:42:24] [18/5269] LLM ok (41.1s)
# [17:42:24] [18/5269] embedding ok view=summary (0.1s)
# [17:42:24] [18/5269] embedding ok view=pattern (0.1s)
# [17:42:24] [18/5269] done case_id=18
#
# [17:42:24] [23/5269] start 上海名老中医医案精选.md#23
# [17:42:31] [19/5269] LLM ok (31.3s)
# [17:42:31] [19/5269] embedding ok view=summary (0.1s)
# [17:42:31] [19/5269] embedding ok view=pattern (0.1s)
# [17:42:31] [19/5269] done case_id=19
#
# [17:42:31] [24/5269] start 上海名老中医医案精选.md#24
# [17:42:40] [20/5269] LLM ok (30.0s)
# [17:42:40] [20/5269] embedding ok view=summary (0.1s)
# [17:42:41] [20/5269] embedding ok view=pattern (0.1s)
# [17:42:41] [20/5269] done case_id=20
#
# [17:42:41] [25/5269] start 上海名老中医医案精选.md#25
# [17:42:51] [21/5269] LLM ok (33.9s)
# [17:42:51] [21/5269] embedding ok view=summary (0.1s)
# [17:42:51] [21/5269] embedding ok view=pattern (0.1s)
# [17:42:51] [21/5269] done case_id=21
#
# [17:42:51] [26/5269] start 上海名老中医医案精选.md#26
# [17:43:06] [24/5269] LLM ok (35.4s)
# [17:43:06] [24/5269] embedding ok view=summary (0.1s)
# [17:43:07] [24/5269] embedding ok view=pattern (0.1s)
# [17:43:07] [24/5269] done case_id=22
#
# [17:43:07] [27/5269] start 上海名老中医医案精选.md#27
# [17:43:07] [22/5269] LLM ok (46.2s)
# [17:43:07] [22/5269] embedding ok view=summary (0.1s)
# [17:43:07] [22/5269] embedding ok view=pattern (0.1s)
# [17:43:07] [22/5269] done case_id=23
#
# [17:43:07] [28/5269] start 上海名老中医医案精选.md#28
# [17:43:24] [23/5269] LLM ok (59.7s)
# [17:43:24] [25/5269] LLM ok (43.7s)
# [17:43:24] [23/5269] embedding ok view=summary (0.1s)
# [17:43:24] [25/5269] embedding ok view=summary (0.1s)
# [17:43:25] [23/5269] embedding ok view=pattern (0.1s)
# [17:43:25] [25/5269] embedding ok view=pattern (0.1s)
# [17:43:25] [23/5269] done case_id=24
#
# [17:43:25] [29/5269] start 上海名老中医医案精选.md#29
# [17:43:25] [25/5269] done case_id=25
#
# [17:43:25] [30/5269] start 上海名老中医医案精选.md#30
# [17:43:30] [26/5269] LLM ok (38.9s)
# [17:43:31] [26/5269] embedding ok view=summary (0.1s)
# [17:43:31] [26/5269] embedding ok view=pattern (0.1s)
# [17:43:31] [26/5269] done case_id=26
#
# [17:43:31] [31/5269] start 上海名老中医医案精选.md#31
# [17:43:36] [28/5269] LLM ok (28.8s)
# [17:43:36] [28/5269] embedding ok view=summary (0.1s)
# [17:43:37] [28/5269] embedding ok view=pattern (0.1s)
# [17:43:37] [28/5269] done case_id=27
#
# [17:43:37] [32/5269] start 上海名老中医医案精选.md#32
# [17:43:39] [27/5269] LLM ok (32.6s)
# [17:43:39] [27/5269] embedding ok view=summary (0.1s)
# [17:43:40] [27/5269] embedding ok view=pattern (0.1s)
# [17:43:40] [27/5269] done case_id=28
#
# [17:43:40] [33/5269] start 上海名老中医医案精选.md#33
# [17:43:45] [31/5269] LLM ok (14.0s)
# [17:43:45] [31/5269] embedding ok view=summary (0.1s)
# [17:43:45] [31/5269] embedding ok view=pattern (0.1s)
# [17:43:45] [31/5269] done case_id=29
#
# [17:43:45] [34/5269] start 上海名老中医医案精选.md#34
# [17:43:47] [30/5269] LLM ok (22.3s)
# [17:43:47] [30/5269] embedding ok view=summary (0.1s)
# [17:43:47] [30/5269] embedding ok view=pattern (0.1s)
# [17:43:47] [30/5269] done case_id=30
#
# [17:43:47] [35/5269] start 上海名老中医医案精选.md#35
# [17:44:08] [29/5269] LLM ok (42.9s)
# [17:44:08] [29/5269] embedding ok view=summary (0.1s)
# [17:44:08] [29/5269] embedding ok view=pattern (0.1s)
# [17:44:08] [29/5269] done case_id=31
#
# [17:44:08] [36/5269] start 上海名老中医医案精选.md#36
# [17:44:09] [34/5269] LLM ok (24.4s)
# [17:44:10] [34/5269] embedding ok view=summary (0.1s)
# [17:44:10] [34/5269] embedding ok view=pattern (0.1s)
# [17:44:10] [34/5269] done case_id=32
#
# [17:44:10] [37/5269] start 上海名老中医医案精选.md#37
# [17:44:11] [33/5269] LLM ok (31.2s)
# [17:44:11] [33/5269] embedding ok view=summary (0.1s)
# [17:44:11] [33/5269] embedding ok view=pattern (0.1s)
# [17:44:11] [33/5269] done case_id=33
#
# [17:44:11] [38/5269] start 上海名老中医医案精选.md#38
# [17:44:17] [32/5269] LLM ok (40.7s)
# [17:44:17] [32/5269] embedding ok view=summary (0.1s)
# [17:44:18] [32/5269] embedding ok view=pattern (0.2s)
# [17:44:18] [32/5269] done case_id=34
#
# [17:44:18] [39/5269] start 上海名老中医医案精选.md#39
# [17:44:33] [38/5269] LLM ok (22.2s)
# [17:44:33] [38/5269] embedding ok view=summary (0.1s)
# [17:44:34] [38/5269] embedding ok view=pattern (0.1s)
# [17:44:34] [38/5269] done case_id=35
#
# [17:44:34] [40/5269] start 上海名老中医医案精选.md#40
# [17:44:36] [36/5269] LLM ok (28.3s)
# [17:44:36] [36/5269] embedding ok view=summary (0.1s)
# [17:44:36] [36/5269] embedding ok view=pattern (0.1s)
# [17:44:36] [36/5269] done case_id=36
#
# [17:44:36] [41/5269] start 上海名老中医医案精选.md#41
# [17:44:40] [37/5269] LLM ok (30.6s)
# [17:44:41] [37/5269] embedding ok view=summary (0.1s)
# [17:44:41] [37/5269] embedding ok view=pattern (0.1s)
# [17:44:41] [37/5269] done case_id=37
#
# [17:44:41] [42/5269] start 上海名老中医医案精选.md#42
# [17:44:47] [39/5269] LLM ok (29.8s)
# [17:44:48] [39/5269] embedding ok view=summary (0.1s)
# [17:44:48] [39/5269] embedding ok view=pattern (0.1s)
# [17:44:48] [39/5269] done case_id=38
#
# [17:44:48] [43/5269] start 上海名老中医医案精选.md#43
# [17:44:52] LLM extract failed attempt=1/3: Extra data: line 56 column 1 (char 1904)
# [17:45:01] [41/5269] LLM ok (24.6s)
# [17:45:01] [41/5269] embedding ok view=summary (0.2s)
# [17:45:01] [41/5269] embedding ok view=pattern (0.1s)
# [17:45:01] [41/5269] done case_id=39
#
# [17:45:01] [44/5269] start 上海名老中医医案精选.md#44
# [17:45:02] [42/5269] LLM ok (21.6s)
# [17:45:03] [42/5269] embedding ok view=summary (0.1s)
# [17:45:03] [42/5269] embedding ok view=pattern (0.1s)
# [17:45:03] [42/5269] done case_id=40
#
# [17:45:03] [45/5269] start 上海名老中医医案精选.md#45
# [17:45:08] [40/5269] LLM ok (34.4s)
# [17:45:08] [40/5269] embedding ok view=summary (0.1s)
# [17:45:08] [40/5269] embedding ok view=pattern (0.1s)
# [17:45:08] [40/5269] done case_id=41
#
# [17:45:08] [46/5269] start 上海名老中医医案精选.md#46
# [17:45:17] [43/5269] LLM ok (28.8s)
# [17:45:17] [43/5269] embedding ok view=summary (0.1s)
# [17:45:17] [43/5269] embedding ok view=pattern (0.1s)
# [17:45:17] [43/5269] done case_id=42
#
# [17:45:17] [47/5269] start 上海名老中医医案精选.md#47
# [17:45:27] [45/5269] LLM ok (24.7s)
# [17:45:28] [45/5269] embedding ok view=summary (0.1s)
# [17:45:28] [45/5269] embedding ok view=pattern (0.1s)
# [17:45:28] [45/5269] done case_id=43
#
# [17:45:28] [48/5269] start 上海名老中医医案精选.md#48
# [17:45:40] [46/5269] LLM ok (31.2s)
# [17:45:40] [46/5269] embedding ok view=summary (0.1s)
# [17:45:40] [46/5269] embedding ok view=pattern (0.1s)
# [17:45:40] [46/5269] done case_id=44
#
# [17:45:40] [49/5269] start 上海名老中医医案精选.md#49
# [17:45:40] [48/5269] LLM ok (12.4s)
# [17:45:40] [48/5269] embedding ok view=summary (0.1s)
# [17:45:40] [48/5269] embedding ok view=pattern (0.1s)
# [17:45:40] [48/5269] done case_id=45
#
# [17:45:40] [50/5269] start 上海名老中医医案精选.md#50
# [17:45:41] [47/5269] LLM ok (24.0s)
# [17:45:41] [47/5269] embedding ok view=summary (0.1s)
# [17:45:41] [47/5269] embedding ok view=pattern (0.1s)
# [17:45:41] [47/5269] done case_id=46
#
# [17:45:41] [51/5269] start 上海名老中医医案精选.md#51
# [17:45:44] [44/5269] LLM ok (42.7s)
# [17:45:44] [44/5269] embedding ok view=summary (0.1s)
# [17:45:44] [44/5269] embedding ok view=pattern (0.1s)
# [17:45:45] [44/5269] done case_id=47
#
# [17:45:45] [52/5269] start 上海名老中医医案精选.md#52
# [17:45:51] [49/5269] LLM ok (11.2s)
# [17:45:51] [49/5269] embedding ok view=summary (0.2s)
# [17:45:52] [49/5269] embedding ok view=pattern (0.1s)
# [17:45:52] [49/5269] done case_id=48
#
# [17:45:52] [53/5269] start 上海名老中医医案精选.md#53
# [17:46:03] LLM extract failed attempt=2/3: Extra data: line 56 column 1 (char 1904)
# [17:46:05] [51/5269] LLM ok (23.4s)
# [17:46:05] [51/5269] embedding ok view=summary (0.1s)
# [17:46:05] [51/5269] embedding ok view=pattern (0.1s)
# [17:46:05] [51/5269] done case_id=49
#
# [17:46:05] [54/5269] start 上海名老中医医案精选.md#54
# [17:46:06] [50/5269] LLM ok (25.5s)
# [17:46:06] [50/5269] embedding ok view=summary (0.1s)
# [17:46:06] [50/5269] embedding ok view=pattern (0.1s)
# [17:46:06] [50/5269] done case_id=50
#
# [17:46:06] [55/5269] start 上海名老中医医案精选.md#55
# [17:46:09] [52/5269] LLM ok (24.9s)
# [17:46:10] [52/5269] embedding ok view=summary (0.1s)
# [17:46:10] [52/5269] embedding ok view=pattern (0.1s)
# [17:46:10] [52/5269] done case_id=51
#
# [17:46:10] [56/5269] start 上海名老中医医案精选.md#56
# [17:46:15] [53/5269] LLM ok (23.6s)
# [17:46:15] [53/5269] embedding ok view=summary (0.1s)
# [17:46:15] [53/5269] embedding ok view=pattern (0.1s)
# [17:46:16] [53/5269] done case_id=52
#
# [17:46:16] [57/5269] start 上海名老中医医案精选.md#57
# [17:46:23] [56/5269] LLM ok (12.9s)
# [17:46:23] [56/5269] embedding ok view=summary (0.1s)
# [17:46:23] [56/5269] embedding ok view=pattern (0.1s)
# [17:46:23] [56/5269] done case_id=53
#
# [17:46:23] [58/5269] start 上海名老中医医案精选.md#58
# [17:46:25] [54/5269] LLM ok (20.2s)
# [17:46:25] [54/5269] embedding ok view=summary (0.1s)
# [17:46:26] [54/5269] embedding ok view=pattern (0.1s)
# [17:46:26] [54/5269] done case_id=54
#
# [17:46:26] [59/5269] start 上海名老中医医案精选.md#59
# [17:46:37] [55/5269] LLM ok (30.2s)
# [17:46:37] [55/5269] embedding ok view=summary (0.1s)
# [17:46:37] [55/5269] embedding ok view=pattern (0.1s)
# [17:46:37] [55/5269] done case_id=55
#
# [17:46:37] [60/5269] start 上海名老中医医案精选.md#60
# [17:46:39] [58/5269] LLM ok (15.7s)
# [17:46:39] [58/5269] embedding ok view=summary (0.1s)
# [17:46:39] [58/5269] embedding ok view=pattern (0.1s)
# [17:46:39] [58/5269] done case_id=56
#
# [17:46:39] [61/5269] start 上海名老中医医案精选.md#61
# [17:46:47] [59/5269] LLM ok (21.6s)
# [17:46:47] [59/5269] embedding ok view=summary (0.2s)
# [17:46:48] [59/5269] embedding ok view=pattern (0.1s)
# [17:46:48] [59/5269] done case_id=57
#
# [17:46:48] [62/5269] start 上海名老中医医案精选.md#62
# [17:46:49] [57/5269] LLM ok (33.3s)
# [17:46:49] [57/5269] embedding ok view=summary (0.1s)
# [17:46:49] [57/5269] embedding ok view=pattern (0.1s)
# [17:46:49] [57/5269] done case_id=58
#
# [17:46:49] [63/5269] start 上海名老中医医案精选.md#63
# [17:46:53] [61/5269] LLM ok (14.4s)
# [17:46:54] [61/5269] embedding ok view=summary (0.1s)
# [17:46:54] [61/5269] embedding ok view=pattern (0.1s)
# [17:46:54] [61/5269] done case_id=59
#
# [17:46:54] [64/5269] start 上海名老中医医案精选.md#64
# [17:46:56] [60/5269] LLM ok (19.0s)
# [17:46:56] [60/5269] embedding ok view=summary (0.1s)
# [17:46:56] [60/5269] embedding ok view=pattern (0.1s)
# [17:46:56] [60/5269] done case_id=60
#
# [17:46:56] [65/5269] start 上海名老中医医案精选.md#65
# [17:47:08] [62/5269] LLM ok (20.4s)
# [17:47:08] [62/5269] embedding ok view=summary (0.1s)
# [17:47:08] [62/5269] embedding ok view=pattern (0.1s)
# [17:47:08] [62/5269] done case_id=61
#
# [17:47:08] [66/5269] start 上海名老中医医案精选.md#66
# [17:47:10] LLM extract failed attempt=3/3: Extra data: line 56 column 1 (char 1904)
# [17:47:10] [35/5269] LLM failed (202.9s)
# [17:47:10] [67/5269] start 上海名老中医医案精选.md#67
# [17:47:13] [63/5269] LLM ok (23.8s)
# [17:47:13] [63/5269] embedding ok view=summary (0.1s)
# [17:47:13] [63/5269] embedding ok view=pattern (0.1s)
# [17:47:13] [63/5269] done case_id=62
#
# [17:47:13] [68/5269] start 上海名老中医医案精选.md#68
# [17:47:27] [64/5269] LLM ok (33.6s)
# [17:47:28] [64/5269] embedding ok view=summary (0.2s)
# [17:47:28] [64/5269] embedding ok view=pattern (0.1s)
# [17:47:28] [64/5269] done case_id=63
#
# [17:47:28] [69/5269] start 上海名老中医医案精选.md#69
# [17:47:34] [66/5269] LLM ok (25.9s)
# [17:47:34] [66/5269] embedding ok view=summary (0.1s)
# [17:47:35] [66/5269] embedding ok view=pattern (0.1s)
# [17:47:35] [66/5269] done case_id=64
#
# [17:47:35] [70/5269] start 上海名老中医医案精选.md#70
# [17:47:48] [69/5269] LLM ok (20.5s)
# [17:47:48] [69/5269] embedding ok view=summary (0.1s)
# [17:47:49] [69/5269] embedding ok view=pattern (0.1s)
# [17:47:49] [69/5269] done case_id=65
#
# [17:47:49] [71/5269] start 上海名老中医医案精选.md#71
# [17:47:51] [68/5269] LLM ok (37.4s)
# [17:47:51] [68/5269] embedding ok view=summary (0.1s)
# [17:47:51] [68/5269] embedding ok view=pattern (0.1s)
# [17:47:51] [68/5269] done case_id=66
#
# [17:47:51] [72/5269] start 上海名老中医医案精选.md#72
# [17:48:03] [65/5269] LLM ok (66.5s)
# [17:48:03] [65/5269] embedding ok view=summary (0.1s)
# [17:48:03] [65/5269] embedding ok view=pattern (0.1s)
# [17:48:03] [65/5269] done case_id=67
#
# [17:48:03] [73/5269] start 上海名老中医医案精选.md#73
# [17:48:04] [67/5269] LLM ok (53.7s)
# [17:48:04] [67/5269] embedding ok view=summary (0.1s)
# [17:48:04] [67/5269] embedding ok view=pattern (0.1s)
# [17:48:04] [67/5269] done case_id=68
#
# [17:48:04] [74/5269] start 上海名老中医医案精选.md#74
# [17:48:23] [74/5269] LLM ok (19.3s)
# [17:48:24] [74/5269] embedding ok view=summary (0.1s)
# [17:48:24] [74/5269] embedding ok view=pattern (0.1s)
# [17:48:24] [74/5269] done case_id=69
#
# [17:48:24] [75/5269] start 上海名老中医医案精选.md#75
# [17:48:24] [71/5269] LLM ok (35.7s)
# [17:48:25] [71/5269] embedding ok view=summary (0.1s)
# [17:48:25] [71/5269] embedding ok view=pattern (0.1s)
# [17:48:25] [71/5269] done case_id=70
#
# [17:48:25] [76/5269] start 上海名老中医医案精选.md#76
# [17:48:26] [72/5269] LLM ok (35.3s)
# [17:48:27] [72/5269] embedding ok view=summary (0.1s)
# [17:48:27] [72/5269] embedding ok view=pattern (0.1s)
# [17:48:27] [72/5269] done case_id=71
#
# [17:48:27] [77/5269] start 上海名老中医医案精选.md#77
# [17:48:43] [70/5269] LLM ok (68.5s)
# [17:48:43] [70/5269] embedding ok view=summary (0.1s)
# [17:48:43] [70/5269] embedding ok view=pattern (0.1s)
# [17:48:43] [70/5269] done case_id=72
#
# [17:48:43] [78/5269] start 上海名老中医医案精选.md#78
# [17:49:01] [73/5269] LLM ok (57.9s)
# [17:49:01] [73/5269] embedding ok view=summary (0.1s)
# [17:49:01] [73/5269] embedding ok view=pattern (0.1s)
# [17:49:01] [73/5269] done case_id=73
#
# [17:49:01] [79/5269] start 上海名老中医医案精选.md#79
# [17:49:02] [77/5269] LLM ok (35.4s)
# [17:49:02] [75/5269] LLM ok (38.6s)
# [17:49:02] [76/5269] LLM ok (37.6s)
# [17:49:02] [77/5269] embedding ok view=summary (0.1s)
# [17:49:02] [77/5269] embedding ok view=pattern (0.1s)
# [17:49:03] [77/5269] done case_id=74
#
# [17:49:03] [80/5269] start 上海名老中医医案精选.md#80
# [17:49:03] [75/5269] embedding ok view=summary (0.1s)
# [17:49:03] [76/5269] embedding ok view=summary (0.2s)
# [17:49:03] [75/5269] embedding ok view=pattern (0.1s)
# [17:49:03] [75/5269] done case_id=75
#
# [17:49:03] [81/5269] start 上海名老中医医案精选.md#81
# [17:49:03] [76/5269] embedding ok view=pattern (0.1s)
# [17:49:03] [76/5269] done case_id=76
#
# [17:49:03] [82/5269] start 上海名老中医医案精选.md#82
# [17:49:09] [78/5269] LLM ok (25.8s)
# [17:49:09] [78/5269] embedding ok view=summary (0.1s)
# [17:49:10] [78/5269] embedding ok view=pattern (0.1s)
# [17:49:10] [78/5269] done case_id=77
#
# [17:49:10] [83/5269] start 上海名老中医医案精选.md#83
# [17:49:33] [82/5269] LLM ok (30.7s)
# [17:49:34] [82/5269] embedding ok view=summary (0.1s)
# [17:49:34] [82/5269] embedding ok view=pattern (0.1s)
# [17:49:34] [82/5269] done case_id=78
#
# [17:49:34] [84/5269] start 上海名老中医医案精选.md#84
# [17:49:37] [80/5269] LLM ok (34.6s)
# [17:49:37] [80/5269] embedding ok view=summary (0.1s)
# [17:49:37] [80/5269] embedding ok view=pattern (0.1s)
# [17:49:37] [80/5269] done case_id=79
#
# [17:49:37] [85/5269] start 上海名老中医医案精选.md#85
# [17:49:45] [81/5269] LLM ok (41.8s)
# [17:49:45] [81/5269] embedding ok view=summary (0.1s)
# [17:49:45] [81/5269] embedding ok view=pattern (0.1s)
# [17:49:45] [81/5269] done case_id=80
#
# [17:49:45] [86/5269] start 上海名老中医医案精选.md#86
# [17:49:47] [79/5269] LLM ok (45.4s)
# [17:49:47] [79/5269] embedding ok view=summary (0.1s)
# [17:49:47] [83/5269] LLM ok (37.4s)
# [17:49:47] [79/5269] embedding ok view=pattern (0.1s)
# [17:49:47] [79/5269] done case_id=81
#
# [17:49:47] [87/5269] start 上海名老中医医案精选.md#87
# [17:49:47] [83/5269] embedding ok view=summary (0.1s)
# [17:49:47] [83/5269] embedding ok view=pattern (0.1s)
# [17:49:47] [83/5269] done case_id=82
#
# [17:49:47] [88/5269] start 上海名老中医医案精选.md#88
# [17:50:00] [84/5269] LLM ok (25.7s)
# [17:50:00] [84/5269] embedding ok view=summary (0.1s)
# [17:50:00] [84/5269] embedding ok view=pattern (0.1s)
# [17:50:00] [84/5269] done case_id=83
#
# [17:50:00] [89/5269] start 上海名老中医医案精选.md#89
# [17:50:09] [87/5269] LLM ok (22.2s)
# [17:50:09] [87/5269] embedding ok view=summary (0.1s)
# [17:50:10] [87/5269] embedding ok view=pattern (0.1s)
# [17:50:10] [87/5269] done case_id=84
#
# [17:50:10] [90/5269] start 上海名老中医医案精选.md#90
# [17:50:17] [85/5269] LLM ok (39.9s)
# [17:50:18] [85/5269] embedding ok view=summary (0.3s)
# [17:50:18] [85/5269] embedding ok view=pattern (0.1s)
# [17:50:18] [85/5269] done case_id=85
#
# [17:50:18] [91/5269] start 上海名老中医医案精选.md#91
# [17:50:27] [86/5269] LLM ok (42.1s)
# [17:50:27] [86/5269] embedding ok view=summary (0.1s)
# [17:50:27] [86/5269] embedding ok view=pattern (0.1s)
# [17:50:27] [86/5269] done case_id=86
#
# [17:50:27] [92/5269] start 上海名老中医医案精选.md#92
# [17:50:41] [88/5269] LLM ok (53.3s)
# [17:50:41] [88/5269] embedding ok view=summary (0.1s)
# [17:50:42] [88/5269] embedding ok view=pattern (1.4s)
# [17:50:42] [88/5269] done case_id=87
#
# [17:50:42] [93/5269] start 上海名老中医医案精选.md#93
# [17:50:56] [89/5269] LLM ok (56.3s)
# [17:50:56] [89/5269] embedding ok view=summary (0.1s)
# [17:50:56] [89/5269] embedding ok view=pattern (0.1s)
# [17:50:56] [89/5269] done case_id=88
#
# [17:50:56] [94/5269] start 上海名老中医医案精选.md#94
# [17:51:17] [92/5269] LLM ok (50.1s)
# [17:51:18] [92/5269] embedding ok view=summary (0.2s)
# [17:51:18] [92/5269] embedding ok view=pattern (0.1s)
# [17:51:18] [92/5269] done case_id=89
#
# [17:51:18] [95/5269] start 上海名老中医医案精选.md#95
# [17:51:21] [90/5269] LLM ok (71.5s)
# [17:51:21] [90/5269] embedding ok view=summary (0.1s)
# [17:51:21] [90/5269] embedding ok view=pattern (0.1s)
# [17:51:21] [90/5269] done case_id=90
#
# [17:51:21] [96/5269] start 上海名老中医医案精选.md#96
# [17:51:22] [91/5269] LLM ok (64.3s)
# [17:51:22] [91/5269] embedding ok view=summary (0.1s)
# [17:51:22] [91/5269] embedding ok view=pattern (0.1s)
# [17:51:22] [91/5269] done case_id=91
#
# [17:51:22] [97/5269] start 上海名老中医医案精选.md#97
# [17:51:48] [94/5269] LLM ok (51.2s)
# [17:51:48] [94/5269] embedding ok view=summary (0.1s)
# [17:51:48] [94/5269] embedding ok view=pattern (0.1s)
# [17:51:48] [94/5269] done case_id=92
#
# [17:51:48] [98/5269] start 上海名老中医医案精选.md#98
# [17:51:52] [93/5269] LLM ok (70.0s)
# [17:51:52] [93/5269] embedding ok view=summary (0.1s)
# [17:51:53] [93/5269] embedding ok view=pattern (0.1s)
# [17:51:53] [93/5269] done case_id=93
#
# [17:51:53] [99/5269] start 上海名老中医医案精选.md#99
# [17:52:21] [99/5269] LLM ok (28.6s)
# [17:52:21] [99/5269] embedding ok view=summary (0.1s)
# [17:52:21] [99/5269] embedding ok view=pattern (0.1s)
# [17:52:21] [99/5269] done case_id=94
#
# [17:52:21] [100/5269] start 上海名老中医医案精选.md#100
# [17:52:22] [96/5269] LLM ok (61.2s)
# [17:52:23] [96/5269] embedding ok view=summary (0.1s)
# [17:52:23] [96/5269] embedding ok view=pattern (0.2s)
# [17:52:23] [96/5269] done case_id=95
#
# [17:52:23] [101/5269] start 上海名老中医医案精选.md#101
# [17:52:28] [95/5269] LLM ok (69.8s)
# [17:52:28] [95/5269] embedding ok view=summary (0.1s)
# [17:52:28] [95/5269] embedding ok view=pattern (0.1s)
# [17:52:28] [95/5269] done case_id=96
#
# [17:52:28] [102/5269] start 上海名老中医医案精选.md#102
# [17:52:32] [98/5269] LLM ok (43.7s)
# [17:52:32] [98/5269] embedding ok view=summary (0.1s)
# [17:52:32] [98/5269] embedding ok view=pattern (0.1s)
# [17:52:32] [98/5269] done case_id=97
#
# [17:52:32] [103/5269] start 上海名老中医医案精选.md#103
# [17:53:15] [101/5269] LLM ok (51.7s)
# [17:53:15] [101/5269] embedding ok view=summary (0.1s)
# [17:53:15] [101/5269] embedding ok view=pattern (0.1s)
# [17:53:15] [101/5269] done case_id=98
#
# [17:53:15] [104/5269] start 上海名老中医医案精选.md#104
# [17:53:24] [103/5269] LLM ok (51.6s)
# [17:53:24] [103/5269] embedding ok view=summary (0.1s)
# [17:53:24] [103/5269] embedding ok view=pattern (0.1s)
# [17:53:24] [103/5269] done case_id=99
#
# [17:53:24] [105/5269] start 上海名老中医医案精选.md#105
# [17:53:28] [100/5269] LLM ok (66.1s)
# [17:53:28] [100/5269] embedding ok view=summary (0.2s)
# [17:53:28] [100/5269] embedding ok view=pattern (0.1s)
# [17:53:28] [100/5269] done case_id=100
#
# [17:53:28] [106/5269] start 上海名老中医医案精选.md#106
# [17:53:34] [102/5269] LLM ok (65.4s)
# [17:53:34] [102/5269] embedding ok view=summary (0.2s)
# [17:53:34] [102/5269] embedding ok view=pattern (0.1s)
# [17:53:34] [102/5269] done case_id=101
#
# [17:53:34] [107/5269] start 上海名老中医医案精选.md#107
# [17:54:18] [106/5269] LLM ok (50.2s)
# [17:54:19] [106/5269] embedding ok view=summary (0.3s)
# [17:54:19] [106/5269] embedding ok view=pattern (0.1s)
# [17:54:19] [106/5269] done case_id=102
#
# [17:54:19] [108/5269] start 上海名老中医医案精选.md#108
# [17:54:25] [105/5269] LLM ok (60.9s)
# [17:54:25] [105/5269] embedding ok view=summary (0.1s)
# [17:54:25] [105/5269] embedding ok view=pattern (0.1s)
# [17:54:25] [105/5269] done case_id=103
#
# [17:54:25] [109/5269] start 上海名老中医医案精选.md#109
# [17:54:34] [107/5269] LLM ok (60.1s)
# [17:54:34] [107/5269] embedding ok view=summary (0.1s)
# [17:54:34] [107/5269] embedding ok view=pattern (0.1s)
# [17:54:34] [107/5269] done case_id=104
#
# [17:54:34] [110/5269] start 上海名老中医医案精选.md#110
# [17:55:16] [108/5269] LLM ok (57.0s)
# [17:55:16] [108/5269] embedding ok view=summary (0.1s)
# [17:55:16] [108/5269] embedding ok view=pattern (0.1s)
# [17:55:16] [108/5269] done case_id=105
#
# [17:55:16] [111/5269] start 上海名老中医医案精选.md#111
# [17:55:18] [109/5269] LLM ok (52.6s)
# [17:55:18] [109/5269] embedding ok view=summary (0.1s)
# [17:55:18] [109/5269] embedding ok view=pattern (0.1s)
# [17:55:18] [109/5269] done case_id=106
#
# [17:55:18] [112/5269] start 上海名老中医医案精选.md#112
# [17:55:24] LLM extract failed attempt=1/3: Request timed out.
# [17:55:43] [110/5269] LLM ok (69.0s)
# [17:55:44] [110/5269] embedding ok view=summary (0.1s)
# [17:55:44] [110/5269] embedding ok view=pattern (0.1s)
# [17:55:44] [110/5269] done case_id=107
#
# [17:55:44] [113/5269] start 上海名老中医医案精选.md#113
# [17:56:09] [111/5269] LLM ok (52.7s)
# [17:56:09] [111/5269] embedding ok view=summary (0.1s)
# [17:56:09] [111/5269] embedding ok view=pattern (0.1s)
# [17:56:09] [111/5269] done case_id=108
#
# [17:56:09] [114/5269] start 上海名老中医医案精选.md#114
# [17:57:16] LLM extract failed attempt=1/3: Request timed out.
# [17:59:19] LLM extract failed attempt=1/3: Request timed out.
# [17:59:27] LLM extract failed attempt=2/3: Request timed out.
# [17:59:45] LLM extract failed attempt=1/3: Request timed out.
# [18:00:11] LLM extract failed attempt=1/3: Request timed out.
# [18:01:20] LLM extract failed attempt=2/3: Request timed out.
# [18:03:23] LLM extract failed attempt=2/3: Request timed out.
# [18:03:31] LLM extract failed attempt=3/3: Request timed out.
# [18:03:31] [97/5269] LLM failed (728.2s)
# [18:03:31] [115/5269] start 上海名老中医医案精选.md#115
# [18:03:49] LLM extract failed attempt=2/3: Request timed out.
# [18:04:14] LLM extract failed attempt=2/3: Request timed out.
# [18:04:14] [115/5269] LLM ok (43.9s)
# [18:04:15] [115/5269] embedding ok view=summary (0.1s)
# [18:04:15] [115/5269] embedding ok view=pattern (0.1s)
# [18:04:15] [115/5269] done case_id=109
#
# [18:04:15] [116/5269] start 上海名老中医医案精选.md#116
# [18:05:23] LLM extract failed attempt=3/3: Request timed out.
# [18:05:23] [104/5269] LLM failed (728.1s)
# [18:05:23] [117/5269] start 上海名老中医医案精选.md#117
# [18:06:32] [117/5269] LLM ok (68.5s)
# [18:06:32] [117/5269] embedding ok view=summary (0.1s)
# [18:06:32] [117/5269] embedding ok view=pattern (0.1s)
# [18:06:32] [117/5269] done case_id=110
#
# [18:06:32] [118/5269] start 上海名老中医医案精选.md#118
# [18:07:03] [118/5269] LLM ok (31.5s)
# [18:07:04] [118/5269] embedding ok view=summary (0.1s)
# [18:07:04] [118/5269] embedding ok view=pattern (0.1s)
# [18:07:04] [118/5269] done case_id=111
#
# [18:07:04] [119/5269] start 上海名老中医医案精选.md#119
# [18:07:26] LLM extract failed attempt=3/3: Request timed out.
# [18:07:26] [112/5269] LLM failed (728.1s)
# [18:07:26] [120/5269] start 上海名老中医医案精选.md#120
# [18:07:52] LLM extract failed attempt=3/3: Request timed out.
# [18:07:52] [113/5269] LLM failed (728.4s)
# [18:07:52] [121/5269] start 上海名老中医医案精选.md#121
# [18:07:57] [119/5269] LLM ok (53.3s)
# [18:07:57] [119/5269] embedding ok view=summary (0.2s)
# [18:07:57] [119/5269] embedding ok view=pattern (0.1s)
# [18:07:57] [119/5269] done case_id=112
#
# [18:07:57] [122/5269] start 上海名老中医医案精选.md#122
# [18:08:11] [122/5269] LLM ok (14.0s)
# [18:08:12] [122/5269] embedding ok view=summary (0.1s)
# [18:08:12] [122/5269] embedding ok view=pattern (0.1s)
# [18:08:12] [122/5269] done case_id=113
#
# [18:08:12] [123/5269] start 上海名老中医医案精选.md#123
# [18:08:16] LLM extract failed attempt=1/3: Request timed out.
# [18:08:17] LLM extract failed attempt=3/3: Request timed out.
# [18:08:17] [114/5269] LLM failed (728.2s)
# [18:08:17] [124/5269] start 上海名老中医医案精选.md#124
# [18:08:35] [120/5269] LLM ok (69.1s)
# [18:08:36] [120/5269] embedding ok view=summary (0.1s)
# [18:08:36] [120/5269] embedding ok view=pattern (0.1s)
# [18:08:36] [120/5269] done case_id=114
#
# [18:08:36] [125/5269] start 上海名老中医医案精选.md#125
# [18:08:38] [123/5269] LLM ok (26.7s)
# [18:08:39] [123/5269] embedding ok view=summary (0.1s)
# [18:08:39] [123/5269] embedding ok view=pattern (0.1s)
# [18:08:39] [123/5269] done case_id=115
#
# [18:08:39] [126/5269] start 上海名老中医医案精选.md#126
# [18:08:41] [121/5269] LLM ok (48.3s)
# [18:08:41] [121/5269] embedding ok view=summary (0.1s)
# [18:08:41] [121/5269] embedding ok view=pattern (0.1s)
# [18:08:41] [121/5269] done case_id=116
#
# [18:08:41] [127/5269] start 上海名老中医医案精选.md#127
# [18:08:50] [124/5269] LLM ok (32.7s)
# [18:08:50] [124/5269] embedding ok view=summary (0.1s)
# [18:08:51] [124/5269] embedding ok view=pattern (0.1s)
# [18:08:51] [124/5269] done case_id=117
#
# [18:08:51] [128/5269] start 上海名老中医医案精选.md#128
# [18:09:02] [125/5269] LLM ok (26.5s)
# [18:09:02] [125/5269] embedding ok view=summary (0.1s)
# [18:09:03] [125/5269] embedding ok view=pattern (0.1s)
# [18:09:03] [125/5269] done case_id=118
#
# [18:09:03] [129/5269] start 上海名老中医医案精选.md#129
# [18:09:06] [126/5269] LLM ok (27.7s)
# [18:09:07] [126/5269] embedding ok view=summary (0.1s)
# [18:09:07] [126/5269] embedding ok view=pattern (0.1s)
# [18:09:07] [126/5269] done case_id=119
#
# [18:09:07] [130/5269] start 上海名老中医医案精选.md#130
# [18:09:08] [127/5269] LLM ok (26.7s)
# [18:09:08] [127/5269] embedding ok view=summary (0.1s)
# [18:09:08] [127/5269] embedding ok view=pattern (0.1s)
# [18:09:08] [127/5269] done case_id=120
#
# [18:09:08] [131/5269] start 上海名老中医医案精选.md#131
# [18:09:25] [129/5269] LLM ok (22.7s)
# [18:09:25] [129/5269] embedding ok view=summary (0.1s)
# [18:09:26] [129/5269] embedding ok view=pattern (0.1s)
# [18:09:26] [129/5269] done case_id=121
#
# [18:09:26] [132/5269] start 上海名老中医医案精选.md#132
# [18:09:28] [128/5269] LLM ok (37.5s)
# [18:09:28] [128/5269] embedding ok view=summary (0.1s)
# [18:09:29] [128/5269] embedding ok view=pattern (0.1s)
# [18:09:29] [128/5269] done case_id=122
#
# [18:09:29] [133/5269] start 上海名老中医医案精选.md#133
# [18:09:33] [130/5269] LLM ok (26.6s)
# [18:09:34] [130/5269] embedding ok view=summary (0.1s)
# [18:09:34] [130/5269] embedding ok view=pattern (0.1s)
# [18:09:34] [130/5269] done case_id=123
#
# [18:09:34] [134/5269] start 上海名老中医医案精选.md#134
# [18:09:39] [131/5269] LLM ok (31.3s)
# [18:09:40] [131/5269] embedding ok view=summary (0.1s)
# [18:09:40] [131/5269] embedding ok view=pattern (0.1s)
# [18:09:40] [131/5269] done case_id=124
#
# [18:09:40] [135/5269] start 上海名老中医医案精选.md#135
# [18:09:41] [133/5269] LLM ok (12.7s)
# [18:09:41] [133/5269] embedding ok view=summary (0.1s)
# [18:09:42] [133/5269] embedding ok view=pattern (0.1s)
# [18:09:42] [133/5269] done case_id=125
#
# [18:09:42] [136/5269] start 上海名老中医医案精选.md#136
# [18:09:51] [134/5269] LLM ok (17.2s)
# [18:09:51] [134/5269] embedding ok view=summary (0.1s)
# [18:09:51] [134/5269] embedding ok view=pattern (0.1s)
# [18:09:51] [134/5269] done case_id=126
#
# [18:09:51] [137/5269] start 上海名老中医医案精选.md#137
# [18:10:03] [132/5269] LLM ok (37.1s)
# [18:10:03] [132/5269] embedding ok view=summary (0.1s)
# [18:10:03] [132/5269] embedding ok view=pattern (0.1s)
# [18:10:03] [132/5269] done case_id=127
#
# [18:10:03] [138/5269] start 上海名老中医医案精选.md#138
# [18:10:05] [135/5269] LLM ok (25.2s)
# [18:10:05] [135/5269] embedding ok view=summary (0.1s)
# [18:10:05] [135/5269] embedding ok view=pattern (0.1s)
# [18:10:05] [135/5269] done case_id=128
#
# [18:10:05] [139/5269] start 上海名老中医医案精选.md#139
# [18:10:14] [137/5269] LLM ok (23.1s)
# [18:10:15] [137/5269] embedding ok view=summary (0.1s)
# [18:10:15] [137/5269] embedding ok view=pattern (0.1s)
# [18:10:15] [137/5269] done case_id=129
#
# [18:10:15] [140/5269] start 上海名老中医医案精选.md#140
# [18:10:16] [136/5269] LLM ok (34.7s)
# [18:10:16] [136/5269] embedding ok view=summary (0.1s)
# [18:10:17] [136/5269] embedding ok view=pattern (0.1s)
# [18:10:17] [136/5269] done case_id=130
#
# [18:10:17] [141/5269] start 上海名老中医医案精选.md#141
# [18:10:29] [138/5269] LLM ok (25.9s)
# [18:10:29] [138/5269] embedding ok view=summary (0.1s)
# [18:10:29] [138/5269] embedding ok view=pattern (0.1s)
# [18:10:29] [138/5269] done case_id=131
#
# [18:10:29] [142/5269] start 上海名老中医医案精选.md#142
# [18:10:35] [141/5269] LLM ok (18.0s)
# [18:10:35] [141/5269] embedding ok view=summary (0.1s)
# [18:10:35] [141/5269] embedding ok view=pattern (0.1s)
# [18:10:35] [141/5269] done case_id=132
#
# [18:10:35] [143/5269] start 上海名老中医医案精选.md#143
# [18:10:50] [143/5269] LLM ok (14.6s)
# [18:10:50] [143/5269] embedding ok view=summary (0.1s)
# [18:10:50] [143/5269] embedding ok view=pattern (0.1s)
# [18:10:50] [143/5269] done case_id=133
#
# [18:10:50] [144/5269] start 上海名老中医医案精选.md#144
# [18:10:54] [140/5269] LLM ok (39.3s)
# [18:10:54] [140/5269] embedding ok view=summary (0.1s)
# [18:10:54] [140/5269] embedding ok view=pattern (0.1s)
# [18:10:54] [140/5269] done case_id=134
#
# [18:10:54] [145/5269] start 上海名老中医医案精选.md#145
# [18:11:02] [139/5269] LLM ok (57.1s)
# [18:11:03] [139/5269] embedding ok view=summary (0.1s)
# [18:11:03] [139/5269] embedding ok view=pattern (0.1s)
# [18:11:03] [139/5269] done case_id=135
#
# [18:11:03] [146/5269] start 上海名老中医医案精选.md#146
# [18:11:14] [144/5269] LLM ok (24.4s)
# [18:11:15] [144/5269] embedding ok view=summary (0.1s)
# [18:11:15] [144/5269] embedding ok view=pattern (0.1s)
# [18:11:15] [144/5269] done case_id=136
#
# [18:11:15] [147/5269] start 上海名老中医医案精选.md#147
# [18:11:19] [145/5269] LLM ok (25.1s)
# [18:11:20] [145/5269] embedding ok view=summary (0.1s)
# [18:11:20] [145/5269] embedding ok view=pattern (0.1s)
# [18:11:20] [145/5269] done case_id=137
#
# [18:11:20] [148/5269] start 上海名老中医医案精选.md#148
# [18:11:22] [142/5269] LLM ok (52.2s)
# [18:11:22] [142/5269] embedding ok view=summary (0.1s)
# [18:11:22] [142/5269] embedding ok view=pattern (0.1s)
# [18:11:22] [142/5269] done case_id=138
#
# [18:11:22] [149/5269] start 上海名老中医医案精选.md#149
# [18:11:38] [146/5269] LLM ok (35.3s)
# [18:11:38] [146/5269] embedding ok view=summary (0.1s)
# [18:11:38] [146/5269] embedding ok view=pattern (0.2s)
# [18:11:38] [146/5269] done case_id=139
#
# [18:11:38] [150/5269] start 上海名老中医医案精选.md#150
# [18:11:43] [149/5269] LLM ok (20.6s)
# [18:11:43] [149/5269] embedding ok view=summary (0.1s)
# [18:11:43] [149/5269] embedding ok view=pattern (0.1s)
# [18:11:43] [149/5269] done case_id=140
#
# [18:11:43] [151/5269] start 上海名老中医医案精选.md#151
# [18:11:45] [148/5269] LLM ok (24.9s)
# [18:11:45] [148/5269] embedding ok view=summary (0.1s)
# [18:11:45] [148/5269] embedding ok view=pattern (0.1s)
# [18:11:45] [148/5269] done case_id=141
#
# [18:11:45] [152/5269] start 上海名老中医医案精选.md#152
# [18:11:52] [147/5269] LLM ok (36.9s)
# [18:11:52] [147/5269] embedding ok view=summary (0.1s)
# [18:11:52] [147/5269] embedding ok view=pattern (0.1s)
# [18:11:52] [147/5269] done case_id=142
#
# [18:11:52] [153/5269] start 上海名老中医医案精选.md#153
# [18:12:09] [151/5269] LLM ok (26.4s)
# [18:12:09] [151/5269] embedding ok view=summary (0.1s)
# [18:12:10] [151/5269] embedding ok view=pattern (0.1s)
# [18:12:10] [151/5269] done case_id=143
#
# [18:12:10] [154/5269] start 上海名老中医医案精选.md#154
# [18:12:14] [152/5269] LLM ok (29.4s)
# [18:12:15] [150/5269] LLM ok (36.1s)
# [18:12:15] [152/5269] embedding ok view=summary (0.1s)
# [18:12:15] [152/5269] embedding ok view=pattern (0.1s)
# [18:12:15] [150/5269] embedding ok view=summary (0.1s)
# [18:12:15] [152/5269] done case_id=144
#
# [18:12:15] [155/5269] start 上海名老中医医案精选.md#155
# [18:12:15] [150/5269] embedding ok view=pattern (0.1s)
# [18:12:15] [150/5269] done case_id=145
#
# [18:12:15] [156/5269] start 上海名老中医医案精选.md#156
# [18:12:16] [153/5269] LLM ok (24.5s)
# [18:12:17] [153/5269] embedding ok view=summary (0.1s)
# [18:12:17] [153/5269] embedding ok view=pattern (0.1s)
# [18:12:17] [153/5269] done case_id=146
#
# [18:12:17] [157/5269] start 上海名老中医医案精选.md#157
# [18:12:20] LLM extract failed attempt=2/3: Request timed out.
# [18:12:40] [154/5269] LLM ok (30.3s)
# [18:12:40] [154/5269] embedding ok view=summary (0.1s)
# [18:12:40] [154/5269] embedding ok view=pattern (0.1s)
# [18:12:40] [154/5269] done case_id=147
#
# [18:12:40] [158/5269] start 上海名老中医医案精选.md#158
# [18:12:45] [156/5269] LLM ok (30.4s)
# [18:12:46] [156/5269] embedding ok view=summary (0.1s)
# [18:12:46] [156/5269] embedding ok view=pattern (0.1s)
# [18:12:46] [156/5269] done case_id=148
#
# [18:12:46] [159/5269] start 上海名老中医医案精选.md#159
# [18:12:57] [155/5269] LLM ok (42.2s)
# [18:12:57] [155/5269] embedding ok view=summary (0.1s)
# [18:12:57] [155/5269] embedding ok view=pattern (0.1s)
# [18:12:57] [155/5269] done case_id=149
#
# [18:12:57] [160/5269] start 上海名老中医医案精选.md#160
# [18:12:58] [157/5269] LLM ok (41.6s)
# [18:12:59] [157/5269] embedding ok view=summary (0.1s)
# [18:12:59] [157/5269] embedding ok view=pattern (0.1s)
# [18:12:59] [157/5269] done case_id=150
#
# [18:12:59] [161/5269] start 上海名老中医医案精选.md#161
# [18:13:10] [159/5269] LLM ok (24.7s)
# [18:13:11] [159/5269] embedding ok view=summary (0.1s)
# [18:13:11] [159/5269] embedding ok view=pattern (0.1s)
# [18:13:11] [159/5269] done case_id=151
#
# [18:13:11] [162/5269] start 上海名老中医医案精选.md#162
# [18:13:23] [158/5269] LLM ok (43.2s)
# [18:13:24] [158/5269] embedding ok view=summary (0.1s)
# [18:13:24] [158/5269] embedding ok view=pattern (0.1s)
# [18:13:24] [158/5269] done case_id=152
#
# [18:13:24] [163/5269] start 上海名老中医医案精选.md#163
# [18:13:26] [160/5269] LLM ok (28.2s)
# [18:13:26] [160/5269] embedding ok view=summary (0.1s)
# [18:13:26] [160/5269] embedding ok view=pattern (0.1s)
# [18:13:26] [160/5269] done case_id=153
#
# [18:13:26] [164/5269] start 上海名老中医医案精选.md#164
# [18:13:35] [161/5269] LLM ok (35.8s)
# [18:13:35] [161/5269] embedding ok view=summary (0.1s)
# [18:13:36] [161/5269] embedding ok view=pattern (0.1s)
# [18:13:36] [161/5269] done case_id=154
#
# [18:13:36] [165/5269] start 上海名老中医医案精选.md#165
# [18:13:40] [162/5269] LLM ok (29.5s)
# [18:13:40] [162/5269] embedding ok view=summary (0.1s)
# [18:13:40] [162/5269] embedding ok view=pattern (0.1s)
# [18:13:40] [162/5269] done case_id=155
#
# [18:13:40] [166/5269] start 上海名老中医医案精选.md#166
# [18:13:47] [163/5269] LLM ok (22.9s)
# [18:13:47] [163/5269] embedding ok view=summary (0.1s)
# [18:13:47] [163/5269] embedding ok view=pattern (0.1s)
# [18:13:47] [163/5269] done case_id=156
#
# [18:13:47] [167/5269] start 上海名老中医医案精选.md#167
# [18:13:51] [164/5269] LLM ok (25.3s)
# [18:13:51] [164/5269] embedding ok view=summary (0.1s)
# [18:13:51] [164/5269] embedding ok view=pattern (0.1s)
# [18:13:51] [164/5269] done case_id=157
#
# [18:13:51] [168/5269] start 上海名老中医医案精选.md#168
# [18:14:00] [165/5269] LLM ok (24.1s)
# [18:14:00] [165/5269] embedding ok view=summary (0.1s)
# [18:14:00] [165/5269] embedding ok view=pattern (0.1s)
# [18:14:00] [165/5269] done case_id=158
#
# [18:14:00] [169/5269] start 上海名老中医医案精选.md#169
# [18:14:18] [168/5269] LLM ok (26.2s)
# [18:14:18] [168/5269] embedding ok view=summary (0.1s)
# [18:14:18] [168/5269] embedding ok view=pattern (0.1s)
# [18:14:18] [168/5269] done case_id=159
#
# [18:14:18] [170/5269] start 上海名老中医医案精选.md#170
# [18:14:22] [167/5269] LLM ok (34.9s)
# [18:14:22] [167/5269] embedding ok view=summary (0.1s)
# [18:14:22] [167/5269] embedding ok view=pattern (0.1s)
# [18:14:22] [167/5269] done case_id=160
#
# [18:14:22] [171/5269] start 上海名老中医医案精选.md#171
# [18:14:23] [166/5269] LLM ok (42.5s)
# [18:14:23] [166/5269] embedding ok view=summary (0.1s)
# [18:14:23] [166/5269] embedding ok view=pattern (0.1s)
# [18:14:23] [166/5269] done case_id=161
#
# [18:14:23] [172/5269] start 上海名老中医医案精选.md#172
# [18:14:23] [169/5269] LLM ok (23.4s)
# [18:14:24] [169/5269] embedding ok view=summary (0.1s)
# [18:14:24] [169/5269] embedding ok view=pattern (0.1s)
# [18:14:24] [169/5269] done case_id=162
#
# [18:14:24] [173/5269] start 上海名老中医医案精选.md#173
# [18:14:48] [170/5269] LLM ok (30.1s)
# [18:14:48] [170/5269] embedding ok view=summary (0.1s)
# [18:14:49] [170/5269] embedding ok view=pattern (0.2s)
# [18:14:49] [170/5269] done case_id=163
#
# [18:14:49] [174/5269] start 上海名老中医医案精选.md#174
# [18:14:52] [171/5269] LLM ok (29.8s)
# [18:14:52] [171/5269] embedding ok view=summary (0.1s)
# [18:14:52] [171/5269] embedding ok view=pattern (0.1s)
# [18:14:52] [171/5269] done case_id=164
#
# [18:14:52] [175/5269] start 上海名老中医医案精选.md#175
# [18:14:58] [172/5269] LLM ok (34.6s)
# [18:14:58] [172/5269] embedding ok view=summary (0.1s)
# [18:14:58] [172/5269] embedding ok view=pattern (0.1s)
# [18:14:58] [172/5269] done case_id=165
#
# [18:14:58] [176/5269] start 上海名老中医医案精选.md#176
# [18:15:10] [173/5269] LLM ok (45.8s)
# [18:15:10] [173/5269] embedding ok view=summary (0.1s)
# [18:15:10] [173/5269] embedding ok view=pattern (0.1s)
# [18:15:10] [173/5269] done case_id=166
#
# [18:15:10] [177/5269] start 上海名老中医医案精选.md#177
# [18:15:25] [174/5269] LLM ok (36.0s)
# [18:15:25] [174/5269] embedding ok view=summary (0.1s)
# [18:15:25] [174/5269] embedding ok view=pattern (0.1s)
# [18:15:25] [174/5269] done case_id=167
#
# [18:15:25] [178/5269] start 上海名老中医医案精选.md#178
# [18:15:47] [177/5269] LLM ok (37.1s)
# [18:15:47] [177/5269] embedding ok view=summary (0.1s)
# [18:15:48] [177/5269] embedding ok view=pattern (0.1s)
# [18:15:48] [177/5269] done case_id=168
#
# [18:15:48] [179/5269] start 上海名老中医医案精选.md#179
# [18:15:51] [176/5269] LLM ok (52.9s)
# [18:15:51] [176/5269] embedding ok view=summary (0.1s)
# [18:15:51] [176/5269] embedding ok view=pattern (0.1s)
# [18:15:51] [176/5269] done case_id=169
#
# [18:15:51] [180/5269] start 上海名老中医医案精选.md#180
# [18:15:54] [175/5269] LLM ok (61.9s)
# [18:15:54] [175/5269] embedding ok view=summary (0.1s)
# [18:15:55] [175/5269] embedding ok view=pattern (0.1s)
# [18:15:55] [175/5269] done case_id=170
#
# [18:15:55] [181/5269] start 上海名老中医医案精选.md#181
# [18:16:23] LLM extract failed attempt=3/3: Request timed out.
# [18:16:23] [116/5269] LLM failed (728.1s)
# [18:16:23] [182/5269] start 上海名老中医医案精选.md#182
# [18:16:24] [179/5269] LLM ok (36.7s)
# [18:16:24] [179/5269] embedding ok view=summary (0.1s)
# [18:16:25] [179/5269] embedding ok view=pattern (0.1s)
# [18:16:25] [179/5269] done case_id=171
#
# [18:16:25] [183/5269] start 上海名老中医医案精选.md#183
# [18:16:32] [180/5269] LLM ok (41.0s)
# [18:16:33] [180/5269] embedding ok view=summary (0.1s)
# [18:16:33] [180/5269] embedding ok view=pattern (0.1s)
# [18:16:33] [180/5269] done case_id=172
#
# [18:16:33] [184/5269] start 上海名老中医医案精选.md#184
# [18:16:34] [178/5269] LLM ok (69.3s)
# [18:16:34] [178/5269] embedding ok view=summary (0.1s)
# [18:16:34] [178/5269] embedding ok view=pattern (0.1s)
# [18:16:34] [178/5269] done case_id=173
#
# [18:16:34] [185/5269] start 上海名老中医医案精选.md#185
# [18:16:53] [181/5269] LLM ok (58.6s)
# [18:16:53] [181/5269] embedding ok view=summary (0.1s)
# [18:16:54] [181/5269] embedding ok view=pattern (0.1s)
# [18:16:54] [181/5269] done case_id=174
#
# [18:16:54] [186/5269] start 上海名老中医医案精选.md#186
# [18:17:02] [184/5269] LLM ok (29.6s)
# [18:17:02] [184/5269] embedding ok view=summary (0.1s)
# [18:17:03] [184/5269] embedding ok view=pattern (0.1s)
# [18:17:03] [184/5269] done case_id=175
#
# [18:17:03] [187/5269] start 上海名老中医医案精选.md#187
# [18:17:10] [185/5269] LLM ok (35.3s)
# [18:17:10] [185/5269] embedding ok view=summary (0.1s)
# [18:17:10] [185/5269] embedding ok view=pattern (0.1s)
# [18:17:10] [185/5269] done case_id=176
#
# [18:17:10] [188/5269] start 上海名老中医医案精选.md#188
# [18:17:15] [182/5269] LLM ok (52.2s)
# [18:17:15] [182/5269] embedding ok view=summary (0.1s)
# [18:17:15] [182/5269] embedding ok view=pattern (0.1s)
# [18:17:15] [182/5269] done case_id=177
#
# [18:17:15] [189/5269] start 上海名老中医医案精选.md#189
# [18:17:17] [183/5269] LLM ok (52.9s)
# [18:17:18] [183/5269] embedding ok view=summary (0.1s)
# [18:17:18] [183/5269] embedding ok view=pattern (0.1s)
# [18:17:18] [183/5269] done case_id=178
#
# [18:17:18] [190/5269] start 上海名老中医医案精选.md#190
# [18:17:24] [186/5269] LLM ok (30.5s)
# [18:17:24] [186/5269] embedding ok view=summary (0.1s)
# [18:17:24] [186/5269] embedding ok view=pattern (0.1s)
# [18:17:24] [186/5269] done case_id=179
#
# [18:17:24] [191/5269] start 上海名老中医医案精选.md#191
# [18:17:29] [190/5269] LLM ok (10.8s)
# [18:17:29] [190/5269] embedding ok view=summary (0.1s)
# [18:17:29] [190/5269] embedding ok view=pattern (0.1s)
# [18:17:29] [190/5269] done case_id=180
#
# [18:17:29] [192/5269] start 上海名老中医医案精选.md#192
# [18:17:45] [188/5269] LLM ok (34.6s)
# [18:17:45] [188/5269] embedding ok view=summary (0.1s)
# [18:17:45] [188/5269] embedding ok view=pattern (0.1s)
# [18:17:45] [188/5269] done case_id=181
#
# [18:17:45] [193/5269] start 上海名老中医医案精选.md#193
# [18:18:00] [191/5269] LLM ok (35.4s)
# [18:18:00] [191/5269] embedding ok view=summary (0.1s)
# [18:18:00] [191/5269] embedding ok view=pattern (0.1s)
# [18:18:00] [191/5269] done case_id=182
#
# [18:18:00] [194/5269] start 上海名老中医医案精选.md#194
# [18:18:05] [187/5269] LLM ok (62.4s)
# [18:18:05] [187/5269] embedding ok view=summary (0.1s)
# [18:18:05] [187/5269] embedding ok view=pattern (0.1s)
# [18:18:05] [187/5269] done case_id=183
#
# [18:18:05] [195/5269] start 上海名老中医医案精选.md#195
# [18:18:18] [193/5269] LLM ok (33.1s)
# [18:18:18] [193/5269] embedding ok view=summary (0.1s)
# [18:18:19] [193/5269] embedding ok view=pattern (0.2s)
# [18:18:19] [193/5269] done case_id=184
#
# [18:18:19] [196/5269] start 上海名老中医医案精选.md#196
# [18:18:19] [192/5269] LLM ok (50.6s)
# [18:18:20] [192/5269] embedding ok view=summary (0.1s)
# [18:18:20] [192/5269] embedding ok view=pattern (0.1s)
# [18:18:20] [192/5269] done case_id=185
#
# [18:18:20] [197/5269] start 上海名老中医医案精选.md#197
# [18:18:27] [189/5269] LLM ok (72.0s)
# [18:18:28] [189/5269] embedding ok view=summary (0.1s)
# [18:18:28] [189/5269] embedding ok view=pattern (0.1s)
# [18:18:28] [189/5269] done case_id=186
#
# [18:18:28] [198/5269] start 上海名老中医医案精选.md#198
# [18:18:33] [194/5269] LLM ok (32.6s)
# [18:18:33] [194/5269] embedding ok view=summary (0.1s)
# [18:18:33] [194/5269] embedding ok view=pattern (0.1s)
# [18:18:33] [194/5269] done case_id=187
#
# [18:18:33] [199/5269] start 上海名老中医医案精选.md#199
# [18:18:46] [195/5269] LLM ok (40.2s)
# [18:18:46] [195/5269] embedding ok view=summary (0.1s)
# [18:18:46] [195/5269] embedding ok view=pattern (0.1s)
# [18:18:46] [195/5269] done case_id=188
#
# [18:18:46] [200/5269] start 上海名老中医医案精选.md#200
# [18:19:03] [199/5269] LLM ok (29.6s)
# [18:19:03] [199/5269] embedding ok view=summary (0.1s)
# [18:19:03] [199/5269] embedding ok view=pattern (0.1s)
# [18:19:03] [199/5269] done case_id=189
#
# [18:19:03] [201/5269] start 上海名老中医医案精选.md#201
# [18:19:18] [198/5269] LLM ok (50.5s)
# [18:19:18] [198/5269] embedding ok view=summary (0.1s)
# [18:19:19] [198/5269] embedding ok view=pattern (0.1s)
# [18:19:19] [198/5269] done case_id=190
#
# [18:19:19] [202/5269] start 上海名老中医医案精选.md#202
# [18:19:22] [196/5269] LLM ok (63.2s)
# [18:19:22] [196/5269] embedding ok view=summary (0.1s)
# [18:19:22] [196/5269] embedding ok view=pattern (0.1s)
# [18:19:22] [196/5269] done case_id=191
#
# [18:19:22] [203/5269] start 上海名老中医医案精选.md#203
# [18:19:28] [201/5269] LLM ok (24.8s)
# [18:19:28] [201/5269] embedding ok view=summary (0.1s)
# [18:19:28] [201/5269] embedding ok view=pattern (0.1s)
# [18:19:28] [201/5269] done case_id=192
#
# [18:19:28] [204/5269] start 上海名老中医医案精选.md#204
# [18:19:34] [197/5269] LLM ok (73.9s)
# [18:19:34] [197/5269] embedding ok view=summary (0.1s)
# [18:19:34] [197/5269] embedding ok view=pattern (0.1s)
# [18:19:34] [197/5269] done case_id=193
#
# [18:19:34] [205/5269] start 上海名老中医医案精选.md#205
# [18:19:47] [202/5269] LLM ok (28.9s)
# [18:19:48] [202/5269] embedding ok view=summary (0.1s)
# [18:19:48] [202/5269] embedding ok view=pattern (0.1s)
# [18:19:48] [202/5269] done case_id=194
#
# [18:19:48] [206/5269] start 上海名老中医医案精选.md#206
# [18:19:48] [200/5269] LLM ok (62.3s)
# [18:19:48] [200/5269] embedding ok view=summary (0.1s)
# [18:19:48] [200/5269] embedding ok view=pattern (0.1s)
# [18:19:48] [200/5269] done case_id=195
#
# [18:19:48] [207/5269] start 上海名老中医医案精选.md#207
# [18:20:00] [205/5269] LLM ok (26.5s)
# [18:20:01] [205/5269] embedding ok view=summary (0.1s)
# [18:20:01] [205/5269] embedding ok view=pattern (0.1s)
# [18:20:01] [205/5269] done case_id=196
#
# [18:20:01] [208/5269] start 上海名老中医医案精选.md#208
# [18:20:03] [203/5269] LLM ok (40.5s)
# [18:20:03] [203/5269] embedding ok view=summary (0.1s)
# [18:20:03] [203/5269] embedding ok view=pattern (0.1s)
# [18:20:03] [203/5269] done case_id=197
#
# [18:20:03] [209/5269] start 上海名老中医医案精选.md#209
# [18:20:04] [204/5269] LLM ok (36.0s)
# [18:20:04] [204/5269] embedding ok view=summary (0.1s)
# [18:20:04] [204/5269] embedding ok view=pattern (0.1s)
# [18:20:04] [204/5269] done case_id=198
#
# [18:20:04] [210/5269] start 上海名老中医医案精选.md#210
# [18:20:18] [206/5269] LLM ok (29.9s)
# [18:20:18] [206/5269] embedding ok view=summary (0.1s)
# [18:20:18] [206/5269] embedding ok view=pattern (0.1s)
# [18:20:18] [206/5269] done case_id=199
#
# [18:20:18] [211/5269] start 上海名老中医医案精选.md#211
# [18:20:21] [207/5269] LLM ok (32.4s)
# [18:20:21] [207/5269] embedding ok view=summary (0.1s)
# ...
#
# [01:29:58] [5208/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#595
# [01:29:59] [5203/5269] LLM ok (30.2s)
# [01:29:59] [5203/5269] embedding ok view=summary (0.1s)
# [01:29:59] [5203/5269] embedding ok view=pattern (0.1s)
# [01:29:59] [5203/5269] done case_id=5179
#
# [01:29:59] [5209/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#596
# [01:30:09] [5207/5269] LLM ok (13.5s)
# [01:30:10] [5207/5269] embedding ok view=summary (0.2s)
# [01:30:10] [5207/5269] embedding ok view=pattern (0.1s)
# [01:30:10] [5207/5269] done case_id=5180
#
# [01:30:10] [5210/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#597
# [01:30:13] [5206/5269] LLM ok (17.7s)
# [01:30:13] [5206/5269] embedding ok view=summary (0.1s)
# [01:30:13] [5206/5269] embedding ok view=pattern (0.1s)
# [01:30:13] [5206/5269] done case_id=5181
#
# [01:30:13] [5211/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#598
# [01:30:22] [5208/5269] LLM ok (24.3s)
# [01:30:22] [5208/5269] embedding ok view=summary (0.1s)
# [01:30:23] [5208/5269] embedding ok view=pattern (0.1s)
# [01:30:23] [5208/5269] done case_id=5182
#
# [01:30:23] [5212/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#599
# [01:30:31] [5211/5269] LLM ok (18.4s)
# [01:30:32] [5211/5269] embedding ok view=summary (0.1s)
# [01:30:32] [5211/5269] embedding ok view=pattern (0.1s)
# [01:30:32] [5211/5269] done case_id=5183
#
# [01:30:32] [5213/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#600
# [01:30:34] [5209/5269] LLM ok (34.7s)
# [01:30:34] [5209/5269] embedding ok view=summary (0.1s)
# [01:30:34] [5209/5269] embedding ok view=pattern (0.1s)
# [01:30:34] [5209/5269] done case_id=5184
#
# [01:30:34] [5214/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#601
# [01:30:44] [5212/5269] LLM ok (21.2s)
# [01:30:44] [5212/5269] embedding ok view=summary (0.1s)
# [01:30:44] [5212/5269] embedding ok view=pattern (0.1s)
# [01:30:44] [5212/5269] done case_id=5185
#
# [01:30:44] [5215/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#602
# [01:30:48] [5210/5269] LLM ok (38.0s)
# [01:30:48] [5210/5269] embedding ok view=summary (0.1s)
# [01:30:48] [5210/5269] embedding ok view=pattern (0.1s)
# [01:30:48] [5210/5269] done case_id=5186
#
# [01:30:48] [5216/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#603
# [01:30:54] [5213/5269] LLM ok (22.1s)
# [01:30:54] [5213/5269] embedding ok view=summary (0.1s)
# [01:30:54] [5213/5269] embedding ok view=pattern (0.1s)
# [01:30:54] [5213/5269] done case_id=5187
#
# [01:30:54] [5217/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#604
# [01:30:59] [5215/5269] LLM ok (14.4s)
# [01:30:59] [5215/5269] embedding ok view=summary (0.1s)
# [01:30:59] [5215/5269] embedding ok view=pattern (0.1s)
# [01:30:59] [5215/5269] done case_id=5188
#
# [01:30:59] [5218/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#605
# [01:31:03] [5214/5269] LLM ok (28.4s)
# [01:31:03] [5214/5269] embedding ok view=summary (0.1s)
# [01:31:03] [5214/5269] embedding ok view=pattern (0.1s)
# [01:31:03] [5214/5269] done case_id=5189
#
# [01:31:03] [5219/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#606
# [01:31:10] [5217/5269] LLM ok (16.0s)
# [01:31:10] [5217/5269] embedding ok view=summary (0.1s)
# [01:31:11] [5217/5269] embedding ok view=pattern (0.1s)
# [01:31:11] [5217/5269] done case_id=5190
#
# [01:31:11] [5220/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#607
# [01:31:21] [5216/5269] LLM ok (32.7s)
# [01:31:21] [5216/5269] embedding ok view=summary (0.1s)
# [01:31:21] [5216/5269] embedding ok view=pattern (0.1s)
# [01:31:21] [5216/5269] done case_id=5191
#
# [01:31:21] [5221/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#608
# [01:31:48] [5220/5269] LLM ok (37.0s)
# [01:31:48] [5220/5269] embedding ok view=summary (0.1s)
# [01:31:48] [5220/5269] embedding ok view=pattern (0.1s)
# [01:31:48] [5220/5269] done case_id=5192
#
# [01:31:48] [5222/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#609
# [01:31:49] [5218/5269] LLM ok (49.9s)
# [01:31:49] [5218/5269] embedding ok view=summary (0.1s)
# [01:31:49] [5218/5269] embedding ok view=pattern (0.1s)
# [01:31:49] [5218/5269] done case_id=5193
#
# [01:31:49] [5223/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#610
# [01:31:51] LLM extract failed attempt=3/3: Request timed out.
# [01:31:51] [5113/5269] LLM failed (728.2s)
# [01:31:51] [5224/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#611
# [01:32:05] [5221/5269] LLM ok (43.7s)
# [01:32:05] [5221/5269] embedding ok view=summary (0.1s)
# [01:32:05] [5221/5269] embedding ok view=pattern (0.1s)
# [01:32:05] [5221/5269] done case_id=5194
#
# [01:32:05] [5225/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#612
# [01:32:15] [5224/5269] LLM ok (23.9s)
# [01:32:15] [5224/5269] embedding ok view=summary (0.1s)
# [01:32:15] [5224/5269] embedding ok view=pattern (0.2s)
# [01:32:15] [5224/5269] done case_id=5195
#
# [01:32:15] [5226/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#613
# [01:32:19] [5223/5269] LLM ok (29.6s)
# [01:32:19] [5223/5269] embedding ok view=summary (0.1s)
# [01:32:19] [5223/5269] embedding ok view=pattern (0.1s)
# [01:32:19] [5223/5269] done case_id=5196
#
# [01:32:19] [5227/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#614
# [01:32:25] [5225/5269] LLM ok (19.8s)
# [01:32:25] [5225/5269] embedding ok view=summary (0.1s)
# [01:32:26] [5225/5269] embedding ok view=pattern (0.1s)
# [01:32:26] [5225/5269] done case_id=5197
#
# [01:32:26] [5228/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#615
# [01:32:28] [5222/5269] LLM ok (39.8s)
# [01:32:28] [5222/5269] embedding ok view=summary (0.1s)
# [01:32:28] [5222/5269] embedding ok view=pattern (0.1s)
# [01:32:28] [5222/5269] done case_id=5198
#
# [01:32:28] [5229/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#616
# [01:32:28] [5226/5269] LLM ok (13.1s)
# [01:32:28] [5226/5269] embedding ok view=summary (0.1s)
# [01:32:29] [5226/5269] embedding ok view=pattern (0.1s)
# [01:32:29] [5226/5269] done case_id=5199
#
# [01:32:29] [5230/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#617
# [01:32:43] [5227/5269] LLM ok (23.4s)
# [01:32:43] [5227/5269] embedding ok view=summary (0.2s)
# [01:32:43] [5227/5269] embedding ok view=pattern (0.1s)
# [01:32:43] [5227/5269] done case_id=5200
#
# [01:32:43] [5231/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#618
# [01:32:49] [5229/5269] LLM ok (20.5s)
# [01:32:49] [5229/5269] embedding ok view=summary (0.1s)
# [01:32:49] [5229/5269] embedding ok view=pattern (0.1s)
# [01:32:49] [5229/5269] done case_id=5201
#
# [01:32:49] [5232/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#619
# [01:32:52] [5228/5269] LLM ok (26.8s)
# [01:32:53] [5228/5269] embedding ok view=summary (0.2s)
# [01:32:53] [5228/5269] embedding ok view=pattern (0.2s)
# [01:32:53] [5228/5269] done case_id=5202
#
# [01:32:53] [5233/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#620
# [01:32:56] [5230/5269] LLM ok (27.5s)
# [01:32:56] [5230/5269] embedding ok view=summary (0.1s)
# [01:32:56] [5230/5269] embedding ok view=pattern (0.1s)
# [01:32:56] [5230/5269] done case_id=5203
#
# [01:32:56] [5234/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#621
# [01:33:07] [5231/5269] LLM ok (24.1s)
# [01:33:07] [5231/5269] embedding ok view=summary (0.1s)
# [01:33:07] [5231/5269] embedding ok view=pattern (0.1s)
# [01:33:08] [5231/5269] done case_id=5204
#
# [01:33:08] [5235/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#622
# [01:33:18] [5234/5269] LLM ok (22.0s)
# [01:33:19] [5234/5269] embedding ok view=summary (0.1s)
# [01:33:19] [5234/5269] embedding ok view=pattern (0.1s)
# [01:33:19] [5234/5269] done case_id=5205
#
# [01:33:19] [5236/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#623
# [01:33:21] [5232/5269] LLM ok (31.9s)
# [01:33:21] [5232/5269] embedding ok view=summary (0.1s)
# [01:33:21] [5232/5269] embedding ok view=pattern (0.1s)
# [01:33:21] [5232/5269] done case_id=5206
#
# [01:33:21] [5237/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#624
# [01:33:21] [5233/5269] LLM ok (28.1s)
# [01:33:21] [5233/5269] embedding ok view=summary (0.1s)
# [01:33:22] [5233/5269] embedding ok view=pattern (0.1s)
# [01:33:22] [5233/5269] done case_id=5207
#
# [01:33:22] [5238/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#625
# [01:33:52] [5235/5269] LLM ok (44.8s)
# [01:33:53] [5235/5269] embedding ok view=summary (0.1s)
# [01:33:53] [5235/5269] embedding ok view=pattern (0.1s)
# [01:33:53] [5235/5269] done case_id=5208
#
# [01:33:53] [5239/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#626
# [01:33:54] [5237/5269] LLM ok (33.0s)
# [01:33:54] [5237/5269] embedding ok view=summary (0.1s)
# [01:33:55] [5237/5269] embedding ok view=pattern (0.1s)
# [01:33:55] [5237/5269] done case_id=5209
#
# [01:33:55] [5240/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#627
# [01:33:56] [5236/5269] LLM ok (37.2s)
# [01:33:56] [5236/5269] embedding ok view=summary (0.1s)
# [01:33:56] [5236/5269] embedding ok view=pattern (0.1s)
# [01:33:56] [5236/5269] done case_id=5210
#
# [01:33:56] [5241/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#628
# [01:34:10] [5239/5269] LLM ok (17.6s)
# [01:34:10] [5239/5269] embedding ok view=summary (0.1s)
# [01:34:11] [5239/5269] embedding ok view=pattern (0.1s)
# [01:34:11] [5239/5269] done case_id=5211
#
# [01:34:11] [5242/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#629
# [01:34:11] [5238/5269] LLM ok (49.5s)
# [01:34:11] [5238/5269] embedding ok view=summary (0.1s)
# [01:34:12] [5238/5269] embedding ok view=pattern (0.1s)
# [01:34:12] [5238/5269] done case_id=5212
#
# [01:34:12] [5243/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#630
# [01:34:20] [5240/5269] LLM ok (25.3s)
# [01:34:20] [5240/5269] embedding ok view=summary (0.1s)
# [01:34:20] [5240/5269] embedding ok view=pattern (0.2s)
# [01:34:20] [5240/5269] done case_id=5213
#
# [01:34:20] [5244/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#631
# [01:34:24] [5242/5269] LLM ok (13.3s)
# [01:34:24] [5242/5269] embedding ok view=summary (0.1s)
# [01:34:24] [5242/5269] embedding ok view=pattern (0.1s)
# [01:34:24] [5242/5269] done case_id=5214
#
# [01:34:24] [5245/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#632
# [01:34:26] [5241/5269] LLM ok (30.1s)
# [01:34:27] [5241/5269] embedding ok view=summary (0.1s)
# [01:34:27] [5241/5269] embedding ok view=pattern (0.1s)
# [01:34:27] [5241/5269] done case_id=5215
#
# [01:34:27] [5246/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#633
# [01:34:35] [5243/5269] LLM ok (23.3s)
# [01:34:35] [5243/5269] embedding ok view=summary (0.1s)
# [01:34:35] [5243/5269] embedding ok view=pattern (0.1s)
# [01:34:35] [5243/5269] done case_id=5216
#
# [01:34:35] [5247/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#634
# [01:34:45] [5245/5269] LLM ok (20.6s)
# [01:34:45] [5245/5269] embedding ok view=summary (0.2s)
# [01:34:45] [5245/5269] embedding ok view=pattern (0.1s)
# [01:34:45] [5245/5269] done case_id=5217
#
# [01:34:45] [5248/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#635
# [01:34:48] [5248/5269] LLM ok (2.4s)
# [01:34:48] [5248/5269] done case_id=5218
#
# [01:34:48] [5249/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#636
# [01:34:49] [5246/5269] LLM ok (22.4s)
# [01:34:49] [5246/5269] embedding ok view=summary (0.1s)
# [01:34:50] [5246/5269] embedding ok view=pattern (0.1s)
# [01:34:50] [5246/5269] done case_id=5219
#
# [01:34:50] [5250/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#637
# [01:34:52] [5250/5269] LLM ok (2.5s)
# [01:34:52] [5250/5269] done case_id=5220
#
# [01:34:52] [5251/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#638
# [01:35:00] [5244/5269] LLM ok (40.1s)
# [01:35:01] [5244/5269] embedding ok view=summary (0.1s)
# [01:35:01] [5244/5269] embedding ok view=pattern (0.1s)
# [01:35:01] [5244/5269] done case_id=5221
#
# [01:35:01] [5252/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#639
# [01:35:04] LLM extract failed attempt=1/3: Request timed out.
# [01:35:07] [5247/5269] LLM ok (31.6s)
# [01:35:07] [5247/5269] embedding ok view=summary (0.1s)
# [01:35:07] [5247/5269] embedding ok view=pattern (0.1s)
# [01:35:07] [5247/5269] done case_id=5222
#
# [01:35:07] [5253/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#640
# [01:35:08] [5251/5269] LLM ok (16.2s)
# [01:35:08] [5251/5269] embedding ok view=summary (0.1s)
# [01:35:09] [5251/5269] embedding ok view=pattern (0.1s)
# [01:35:09] [5251/5269] done case_id=5223
#
# [01:35:09] [5254/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#641
# [01:35:14] [5249/5269] LLM ok (26.7s)
# [01:35:15] [5249/5269] embedding ok view=summary (0.1s)
# [01:35:15] [5249/5269] embedding ok view=pattern (0.1s)
# [01:35:15] [5249/5269] done case_id=5224
#
# [01:35:15] [5255/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#642
# [01:35:26] [5253/5269] LLM ok (18.4s)
# [01:35:26] [5253/5269] embedding ok view=summary (0.1s)
# [01:35:26] [5253/5269] embedding ok view=pattern (0.1s)
# [01:35:26] [5253/5269] done case_id=5225
#
# [01:35:26] [5256/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#643
# [01:35:30] [5252/5269] LLM ok (29.2s)
# [01:35:30] [5252/5269] embedding ok view=summary (0.1s)
# [01:35:30] [5252/5269] embedding ok view=pattern (0.1s)
# [01:35:30] [5252/5269] done case_id=5226
#
# [01:35:30] [5257/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#644
# [01:35:32] [5255/5269] LLM ok (17.1s)
# [01:35:32] [5255/5269] embedding ok view=summary (0.1s)
# [01:35:32] [5255/5269] embedding ok view=pattern (0.1s)
# [01:35:32] [5255/5269] done case_id=5227
#
# [01:35:32] [5258/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#645
# [01:35:34] [5254/5269] LLM ok (25.8s)
# [01:35:35] [5254/5269] embedding ok view=summary (0.1s)
# [01:35:35] [5254/5269] embedding ok view=pattern (0.1s)
# [01:35:35] [5254/5269] done case_id=5228
#
# [01:35:35] [5259/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#646
# [01:35:45] [5256/5269] LLM ok (19.0s)
# [01:35:45] [5256/5269] embedding ok view=summary (0.1s)
# [01:35:45] [5256/5269] embedding ok view=pattern (0.1s)
# [01:35:45] [5256/5269] done case_id=5229
#
# [01:35:45] [5260/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#647
# [01:35:47] [5258/5269] LLM ok (15.1s)
# [01:35:47] [5258/5269] embedding ok view=summary (0.1s)
# [01:35:48] [5258/5269] embedding ok view=pattern (0.1s)
# [01:35:48] [5258/5269] done case_id=5230
#
# [01:35:48] [5261/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#648
# [01:36:00] [5261/5269] LLM ok (12.1s)
# [01:36:00] [5261/5269] embedding ok view=summary (0.1s)
# [01:36:00] [5261/5269] embedding ok view=pattern (0.1s)
# [01:36:00] [5261/5269] done case_id=5231
#
# [01:36:00] [5262/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#649
# [01:36:07] [5260/5269] LLM ok (21.7s)
# [01:36:07] [5260/5269] embedding ok view=summary (0.1s)
# [01:36:07] [5260/5269] embedding ok view=pattern (0.1s)
# [01:36:07] [5260/5269] done case_id=5232
#
# [01:36:07] [5263/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#650
# [01:36:08] [5259/5269] LLM ok (33.7s)
# [01:36:09] [5259/5269] embedding ok view=summary (0.1s)
# [01:36:09] [5259/5269] embedding ok view=pattern (0.1s)
# [01:36:09] [5259/5269] done case_id=5233
#
# [01:36:09] [5264/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#651
# [01:36:14] [5263/5269] LLM ok (6.9s)
# [01:36:14] [5263/5269] embedding ok view=summary (0.1s)
# [01:36:15] [5263/5269] embedding ok view=pattern (0.1s)
# [01:36:15] [5263/5269] done case_id=5234
#
# [01:36:15] [5265/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#652
# [01:36:20] [5264/5269] LLM ok (10.9s)
# [01:36:20] [5264/5269] embedding ok view=summary (0.1s)
# [01:36:20] [5264/5269] embedding ok view=pattern (0.1s)
# [01:36:20] [5264/5269] done case_id=5235
#
# [01:36:20] [5266/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#653
# [01:36:23] [5265/5269] LLM ok (8.0s)
# [01:36:23] [5265/5269] embedding ok view=summary (0.1s)
# [01:36:23] [5265/5269] embedding ok view=pattern (0.1s)
# [01:36:23] [5265/5269] done case_id=5236
#
# [01:36:23] [5267/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#654
# [01:36:24] [5262/5269] LLM ok (24.4s)
# [01:36:25] [5262/5269] embedding ok view=summary (0.1s)
# [01:36:25] [5262/5269] embedding ok view=pattern (0.2s)
# [01:36:25] [5262/5269] done case_id=5237
#
# [01:36:25] [5268/5269] start 中国现代名中医医案精粹（第6集）_已处理.md#655
# [01:36:26] [5257/5269] LLM ok (55.4s)
# [01:36:26] [5257/5269] embedding ok view=summary (0.1s)
# [01:36:26] [5257/5269] embedding ok view=pattern (0.1s)
# [01:36:26] [5257/5269] done case_id=5238
#
# [01:36:26] [5269/5269] start 百家名医临证验案传真.md#1
# [01:36:29] [5266/5269] LLM ok (9.4s)
# [01:36:30] [5266/5269] embedding ok view=summary (0.1s)
# [01:36:30] [5266/5269] embedding ok view=pattern (0.2s)
# [01:36:30] [5266/5269] done case_id=5239
#
# [01:36:31] [5267/5269] LLM ok (8.5s)
# [01:36:32] [5267/5269] embedding ok view=summary (0.1s)
# [01:36:32] [5267/5269] embedding ok view=pattern (0.1s)
# [01:36:32] [5267/5269] done case_id=5240
#
# [01:36:35] [5268/5269] LLM ok (9.9s)
# [01:36:35] [5268/5269] embedding ok view=summary (0.1s)
# [01:36:35] [5268/5269] embedding ok view=pattern (0.1s)
# [01:36:35] [5268/5269] done case_id=5241
#
# [01:36:56] [5269/5269] LLM ok (29.9s)
# [01:36:56] [5269/5269] embedding ok view=summary (0.1s)
# [01:36:56] [5269/5269] embedding ok view=pattern (0.1s)
# [01:36:56] [5269/5269] done case_id=5242
#
# [01:37:30] [5219/5269] LLM ok (387.2s)
# [01:37:31] [5219/5269] embedding ok view=summary (0.1s)
# [01:37:31] [5219/5269] embedding ok view=pattern (0.1s)
# [01:37:31] [5219/5269] done case_id=5243
#
# [01:37:31] ingest done success=5243 fail=26

# %%
# ==================== RAG 检索（metadata + vector + rerank） ====================

class TCMCaseRAG:
    def _query_embedding(self, text: str) -> List[float]:
        url = f"{EMBEDDING_URL}/v1/embeddings"
        headers = {"Content-Type": "application/json", "Authorization": f"Bearer {API_KEY}"}
        payload = {"model": EMBEDDING_MODEL, "input": [text]}
        r = requests.post(url, headers=headers, json=payload, timeout=EMBED_TIMEOUT_S)
        r.raise_for_status()
        full = r.json()["data"][0]["embedding"]
        return full[:TARGET_DIM]

    def _rerank(self, query: str, candidates: List[Dict], top_k: int) -> List[Dict]:
        url = f"{RERANKER_URL}/v1/rerank"
        headers = {"Content-Type": "application/json", "Authorization": f"Bearer {API_KEY}"}
        docs = [c.get("summary") or c.get("content", "")[:300] for c in candidates]
        payload = {"model": RERANKER_MODEL, "query": query, "documents": docs, "top_k": min(top_k, len(docs))}
        r = requests.post(url, headers=headers, json=payload, timeout=RERANK_TIMEOUT_S)
        r.raise_for_status()
        out = []
        for item in r.json()["results"]:
            idx = item["index"]
            c = candidates[idx]
            c["rerank_score"] = item["relevance_score"]
            out.append(c)
        return out

    def search(self, query: str, filters: Optional[Dict] = None, top_k: int = 10, rerank_top_k: int = 5, view: str = "summary") -> List[Dict]:
        qv = self._query_embedding(query)

        conn = psycopg2.connect(**DB_CONFIG)
        cur = conn.cursor()

        sql = """
            SELECT
                c.id, c.source_md, c.case_index, c.summary, c.sex, c.age, c.tcm_pattern,
                c.tcm_diagnosis, c.western_diagnosis, c.clean_json, e.content,
                1 - (e.embedding <=> %s::vector) AS similarity
            FROM tcm_case c
            JOIN tcm_case_embedding e ON c.id = e.case_id
            WHERE e.view = %s
        """
        params = [qv, view]

        if filters:
            if filters.get("sex"):
                sql += " AND c.sex = %s"
                params.append(filters["sex"])
            if filters.get("age_min") is not None:
                sql += " AND c.age >= %s"
                params.append(filters["age_min"])
            if filters.get("age_max") is not None:
                sql += " AND c.age <= %s"
                params.append(filters["age_max"])
            if filters.get("tcm_pattern"):
                sql += " AND c.tcm_pattern ILIKE %s"
                params.append(f"%{filters['tcm_pattern']}%")

        sql += " ORDER BY similarity DESC LIMIT %s;"
        params.append(top_k)

        cur.execute(sql, params)
        rows = cur.fetchall()
        cur.close()
        conn.close()

        candidates = []
        for r in rows:
            candidates.append(
                {
                    "case_id": r[0],
                    "source_md": r[1],
                    "case_index": r[2],
                    "summary": r[3],
                    "sex": r[4],
                    "age": r[5],
                    "tcm_pattern": r[6],
                    "tcm_diagnosis": r[7],
                    "western_diagnosis": r[8],
                    "clean_json": r[9],
                    "content": r[10],
                    "similarity": float(r[11]),
                }
            )

        if not candidates:
            return []

        return self._rerank(query, candidates, rerank_top_k)


rag = TCMCaseRAG()

q = "失眠多梦，心烦易怒，如何治疗？"
res = rag.search(q, top_k=5, rerank_top_k=3)
print("RAG test:", q)
for i, r in enumerate(res, 1):
    print(i, r["source_md"], r["case_index"], f"sim={r['similarity']:.3f}", f"rerank={r.get('rerank_score', 0):.3f}")

# %%
# ==================== LangGraph Agent（parse → retrieve → generate） ====================

from langgraph.graph import StateGraph, END
import operator


class AgentState(TypedDict):
    query: str
    parsed_query: dict
    retrieved_cases: list
    answer: str
    messages: Annotated[Sequence[str], operator.add]


def parse_query_node(state: AgentState) -> AgentState:
    query = state["query"]

    prompt = f"""请把用户问题解析成检索用 JSON。只输出 JSON：
{{
  \"filters\": {{\"sex\": \"男\"|\"女\"|null, \"age_min\": int|null, \"age_max\": int|null, \"tcm_pattern\": str|null}},
  \"rewritten_query\": str
}}

用户问题: {query}
"""

    try:
        resp = llm_client.chat.completions.create(
            model=LLM_MODEL,
            messages=[
                {"role": "system", "content": "只输出 JSON。"},
                {"role": "user", "content": prompt},
            ],
            temperature=0,
            timeout=LLM_TIMEOUT_S,
        )
        parsed = json.loads(strip_code_fence(resp.choices[0].message.content))
        state["parsed_query"] = parsed
        state["messages"].append(f"parse: {parsed}")
    except Exception as e:
        state["parsed_query"] = {"filters": {}, "rewritten_query": query}
        state["messages"].append(f"parse_failed: {str(e)[:80]}")

    return state


def retrieve_cases_node(state: AgentState) -> AgentState:
    parsed = state.get("parsed_query") or {}
    filters = {k: v for k, v in (parsed.get("filters") or {}).items() if v is not None}
    rewritten = parsed.get("rewritten_query") or state["query"]

    try:
        results = rag.search(rewritten, filters=filters or None, top_k=8, rerank_top_k=5)
        state["retrieved_cases"] = results
        state["messages"].append(f"retrieve: {len(results)} cases")
    except Exception as e:
        state["retrieved_cases"] = []
        state["messages"].append(f"retrieve_failed: {str(e)[:80]}")

    return state


def generate_answer_node(state: AgentState) -> AgentState:
    query = state["query"]
    cases = state.get("retrieved_cases") or []

    if not cases:
        state["answer"] = "没有检索到相关医案。"
        state["messages"].append("generate: no cases")
        return state

    ctx = ""
    for i, c in enumerate(cases[:3], 1):
        ctx += f"\n[医案{i}] {c['source_md']}#{c['case_index']} | {c.get('sex')}/{c.get('age')} | {c.get('tcm_pattern')}\n"
        ctx += f"摘要: {c.get('summary','')}\n"

    prompt = f"""你是中医专家。基于检索到的医案回答用户问题。

用户问题: {query}

检索到的医案摘要:
{ctx}

要求:
- 结合医案给出辨证思路、治法和用药方向
- 引用医案编号
- 300字内

回答:"""

    try:
        resp = llm_client.chat.completions.create(
            model=LLM_MODEL,
            messages=[
                {"role": "system", "content": "你是中医专家。"},
                {"role": "user", "content": prompt},
            ],
            temperature=0.3,
            timeout=LLM_TIMEOUT_S,
        )
        state["answer"] = resp.choices[0].message.content.strip()
        state["messages"].append("generate: ok")
    except Exception as e:
        state["answer"] = f"生成失败: {str(e)[:120]}"
        state["messages"].append("generate_failed")

    return state


def build_agent():
    g = StateGraph(AgentState)
    g.add_node("parse", parse_query_node)
    g.add_node("retrieve", retrieve_cases_node)
    g.add_node("generate", generate_answer_node)

    g.set_entry_point("parse")
    g.add_edge("parse", "retrieve")
    g.add_edge("retrieve", "generate")
    g.add_edge("generate", END)
    return g.compile()


agent = build_agent()
print("✅ agent ready")
# Out:
# 🔍 测试 RAG 检索
#
# 查询: 失眠多梦，心烦易怒，如何治疗？
# 召回 5 个医案:
#
# 1. [上海名老中医医案精选.md#7] 相似度:0.776 Rerank:0.884
#    患者: 女/31岁 | 证型: 肝亢肾虚
#    摘要: 主要症状为长期失眠、多梦、夜尿频急、头胀痛、颈部板滞、手麻、心烦紧张、腰酸腿麻；证型为肝亢肾虚；核心治法为平肝益肾安神；经加味龙牡汤合仙地汤加减治疗，二诊后睡眠明显改善，诸症减轻，疗效显著。...
#
# 2. [上海名老中医医案精选.md#9] 相似度:0.715 Rerank:0.875
#    患者: 女/42岁 | 证型: 肝郁阳亢，气血痹阻
#    摘要: 患者主要症状为长期失眠伴入睡困难、多梦、头晕头胀、口干、心慌、便秘等，证属肝郁阳亢、气血痹阻。核心治法为解郁平肝、通络活血、清热安神，方用甘麦苦参汤合加味柴胡龙牡汤加减。经治疗后睡眠明显改善，诸症减轻...
#
# 3. [上海名老中医医案精选.md#8] 相似度:0.732 Rerank:0.874
#    患者: 女/24岁 | 证型: 肝木偏旺，瘀热交阻
#    摘要: 主要症状为失眠、多梦易醒、心烦易怒、颈板不适；证型为肝木偏旺，瘀热交阻；核心治法为平肝抑木，清热化瘀；经三诊治疗后夜寐恢复正常，疗效显著。...
#
# 4. [上海名老中医医案精选.md#15] 相似度:0.745 Rerank:0.872
#    患者: 男/69岁 | 证型: 肝阳上亢化风，瘀热交阻
#    摘要: 主要症状为夜寐多梦、噩梦、说梦话、梦中紧张及踢打动作；证型为肝阳上亢化风，瘀热交阻；核心治法为平肝潜阳息风，清热活血安神；经28剂中药治疗后症状明显减轻，疗效显著。...
#
# 5. [上海名老中医医案精选.md#10] 相似度:0.723 Rerank:0.871
#    患者: 女/50岁 | 证型: 肝亢肾虚
#    摘要: 主要症状为失眠、多梦、早醒、烘热汗出、腰酸痛、尿频等；证型为肝亢肾虚；核心治法为益肾平肝、解郁安神；疗效显著，睡眠明显改善，伴随症状缓解。...
#
#
# 查询: 女性更年期失眠怎么办？
# 过滤: {'sex': '女', 'age_min': 40, 'age_max': 55}
# 召回 5 个医案:
#
# 1. [上海名老中医医案精选.md#20] 女/46岁 | 肝亢肾虚
#    Rerank分数: 0.833
# 2. [上海名老中医医案精选.md#10] 女/50岁 | 肝亢肾虚
#    Rerank分数: 0.832
# 3. [上海名老中医医案精选.md#5] 女/47岁 | 肝亢肾虚，湿热下注
#    Rerank分数: 0.825
# 4. [上海名老中医医案精选.md#9] 女/42岁 | 肝郁阳亢，气血痹阻
#    Rerank分数: 0.822
# 5. [上海名老中医医案精选.md#3] 女/48岁 | 肝胆失疏，湿热蕴结
#    Rerank分数: 0.820

# %%
# ==================== 示例调用 ====================

def run(query: str):
    state = {"query": query, "parsed_query": {}, "retrieved_cases": [], "answer": "", "messages": []}
    out = agent.invoke(state)
    print("=" * 80)
    print("Q:", query)
    print("--- messages ---")
    for m in out["messages"]:
        print(m)
    print("--- answer ---")
    print(out["answer"])
    return out


run("我最近失眠多梦，心烦易怒，中医怎么治疗？")
run("50岁女性，绝经后失眠严重，烘热汗出，腰酸，怎么办？")

# %% [markdown]
# # AgentState 工作原理（通俗解释）
#
# `AgentState` 可以理解成 **Agent 在流水线里传递的一张“工作表”**。每跑完一个节点，就在这张表上“填几栏信息”，交给下一个节点继续用。
#
# 它包含这些字段：
#
# - `query`
#   - 用户原始问题。
#   - 例："50岁女性绝经后失眠严重怎么办？"
#
# - `parsed_query`
#   - **把用户问题翻译成检索语言**后的结果。
#   - 里面通常有：
#     - `filters`：硬过滤条件（性别、年龄段、证型关键词等）
#     - `rewritten_query`：为了向量检索更准，对问题做的“检索改写”
#
# - `retrieved_cases`
#   - RAG 检索得到的候选医案列表（已经做过向量召回 + rerank 排序）。
#
# - `answer`
#   - 最终要给用户的回答文本。
#
# - `messages`
#   - **流水线日志**。每个节点会往里面追加一句话，帮助你看清 agent 每一步到底做了什么。
#
# ## 3 个节点分别干什么
#
# ### 1) `parse` 节点（parse_query_node）
# 把自然语言问题变成“检索参数”。
#
# - 输入：`query`
# - 输出：写入 `parsed_query`
#
# 通俗理解：
# - 用户说“50岁女性绝经后失眠、烘热汗出”
# - 这个节点会提取：
#   - 过滤条件：`sex=女`，`age_min=45`，`age_max=55`（如果能推断）
#   - 改写查询：把口语变成更像“关键词+症状+证候”的检索句子
#
# ### 2) `retrieve` 节点（retrieve_cases_node）
# 真正去数据库里“找医案”。
#
# - 输入：`parsed_query`
# - 执行：
#   - 先用 `rewritten_query` 生成 embedding（并截断到 `TARGET_DIM`，与入库一致）
#   - pgvector 做向量相似度召回（可叠加 filters）
#   - reranker 再对召回结果重排
# - 输出：写入 `retrieved_cases`
#
# 通俗理解：
# - 先“粗找”：向量找相似医案
# - 再“精排”：reranker 把最相关的排前面
#
# ### 3) `generate` 节点（generate_answer_node）
# 把检索到的医案摘要当作“参考资料”，让 LLM 生成回答。
#
# - 输入：`query` + `retrieved_cases`
# - 输出：写入 `answer`
#
# 通俗理解：
# - 这个节点不再“凭空回答”，而是：
#   - 先把 top3 医案拼成上下文
#   - 再让 LLM 结合这些医案去总结：证型、治法、用药方向
#
# ---
#
# 如果你希望 `parse` 不要“过度过滤”（导致检索 0 条），我可以在 `parse_query_node` 里加一个策略：
# - **filters 只抽取 sex/age，不强行给 tcm_pattern**；
# - 或者 `tcm_pattern` 只有在用户明确说了某证型才填。

# %% [markdown]
# # 运行顺序
#
# 1. 运行 `统一配置`
# 2. 运行 `LLM 结构化抽取`
# 3. 运行 `建表 + 入库（前 N 条）`
# 4. 运行 `RAG 检索`
# 5. 运行 `LangGraph Agent`
# 6. 运行 `示例调用`
#
# 如果你遇到 LLM 超时：
# - 优先降低 `MAX_WORKERS` 到 1-2
# - 或提高 `LLM_TIMEOUT_S`
# - 或把 `content[:5000]` 调小（比如 3000）
